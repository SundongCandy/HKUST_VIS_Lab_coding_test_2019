# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#          Position                                  Track Name  \
# 0               1                  Reggaetón Lento (Bailemos)
# 1               2                                    Chantaje
# 2               3                   Otra Vez (feat. J Balvin)
# 3               4                                Vente Pa' Ca
# 4               5                                      Safari
# 5               6                                La Bicicleta
# 6               7                                  Ay Mi Dios
# 7               8                          Andas En Mi Cabeza
# 8               9                                 Traicionera
# 9              10                                 Shaky Shaky
# 10             11                                  Vacaciones
# 11             12                      Dile Que Tu Me Quieres
# 12             13                             Let Me Love You
# 13             14                            DUELE EL CORAZON
# 14             15                                     Chillax
# 15             16                              Borro Cassette
# 16             17                                   One Dance
# 17             18                                      Closer
# 18             19                                     Starboy
# 19             20                             Desde Esa Noche
# 20             21                            Don't Wanna Know
# 21             22                                 La Gozadera
# 22             23                                   24K Magic
# 23             24            Me Llamas (feat. Maluma) - Remix
# 24             25                                Cuatro Babys
# 25             26                                      My Way
# 26             27                     Gyal You A Party Animal
# 27             28                               Baila Conmigo
# 28             29             Gyal You A Party Animal - Remix
# 29             30  We Don't Talk Anymore (feat. Selena Gomez)
# ...           ...                                         ...
# 3441167       171                                        失落沙洲
# 3441168       172                                          晴天
# 3441169       173                                        Kong
# 3441170       174                             Congratulations
# 3441171       175                               There for You
# 3441172       176                               XO TOUR Llif3
# 3441173       177                                          草原
# 3441174       178                           Don't Let Me Down
# 3441175       179                                     只知感覺失了蹤
# 3441176       180                                        修煉愛情
# 3441177       181      Pretty Girl - Cheat Codes X CADE Remix
# 3441178       182                                          心淡
# 3441179       183                    Friends (with BloodPop®)
# 3441180       184                                        高山低谷
# 3441181       185                                        死亡之吻
# 3441182       186                                          無賴
# 3441183       187                                       月球下的人
# 3441184       188                                     Gashina
# 3441185       189                                          七友
# 3441186       190                                     那一年零一個月
# 3441187       191               我多喜歡你,你會知道 - 網劇《致我們單純的小美好》推廣曲
# 3441188       192                                        富士山下
# 3441189       193                               Unforgettable
# 3441190       194                          Castle on the Hill
# 3441191       195                           Whatever It Takes
# 3441192       196                          More Than You Know
# 3441193       197                                      Issues
# 3441194       198                                 Tuo Fei Lun
# 3441195       199                                          面具
# 3441196       200                                  Let Her Go
#
#                      Artist  Streams  \
# 0                      CNCO    19272
# 1                   Shakira    19270
# 2             Zion & Lennox    15761
# 3              Ricky Martin    14954
# 4                  J Balvin    14269
# 5              Carlos Vives    12843
# 6                  IAmChino    10986
# 7             Chino & Nacho    10653
# 8           Sebastian Yatra     9807
# 9              Daddy Yankee     9612
# 10                    Wisin     9611
# 11                    Ozuna     8982
# 12                 DJ Snake     8834
# 13         Enrique Iglesias     8309
# 14                  Farruko     7822
# 15                   Maluma     7586
# 16                    Drake     7472
# 17         The Chainsmokers     7416
# 18               The Weeknd     7006
# 19                   Thalía     6779
# 20                 Maroon 5     6582
# 21            Gente De Zona     6521
# 22               Bruno Mars     6261
# 23                  Piso 21     6237
# 24                   Maluma     6028
# 25            Calvin Harris     5723
# 26             Charly Black     5601
# 27               Juan Magán     5586
# 28             Charly Black     5541
# 29             Charlie Puth     5362
# ...                     ...      ...
# 3441167            LaLa Hsu     2381
# 3441168            Jay Chou     2347
# 3441169           Justin Lo     2331
# 3441170         Post Malone     2309
# 3441171       Martin Garrix     2304
# 3441172        Lil Uzi Vert     2295
# 3441173            Phil Lam     2286
# 3441174    The Chainsmokers     2277
# 3441175           Dear Jane     2272
# 3441176              JJ Lin     2255
# 3441177    Maggie Lindemann     2251
# 3441178           Joey Yung     2248
# 3441179       Justin Bieber     2223
# 3441180            Phil Lam     2220
# 3441181         Kelvin Kwan     2219
# 3441182        Ronald Cheng     2204
# 3441183             Gin Lee     2176
# 3441184               SUNMI     2171
# 3441185        Edmond Leung     2166
# 3441186         Feanna Wong     2165
# 3441187                 王俊琪     2148
# 3441188          Eason Chan     2144
# 3441189      French Montana     2134
# 3441190          Ed Sheeran     2134
# 3441191     Imagine Dragons     2130
# 3441192  Axwell /\ Ingrosso     2126
# 3441193      Julia Michaels     2117
# 3441194          Eason Chan     2112
# 3441195          Alfred Hui     2102
# 3441196           Passenger     2088
#
#                                                        URL        Date Region
# 0        https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01     ec
# 1        https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01     ec
# 2        https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01     ec
# 3        https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01     ec
# 4        https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01     ec
# 5        https://open.spotify.com/track/0sXvAOmXgjR2QUq...  2017-01-01     ec
# 6        https://open.spotify.com/track/6stYbAJgTszHAHZ...  2017-01-01     ec
# 7        https://open.spotify.com/track/5mey7CLLuFToM2P...  2017-01-01     ec
# 8        https://open.spotify.com/track/5J1c3M4EldCfNxX...  2017-01-01     ec
# 9        https://open.spotify.com/track/58IL315gMSTD37D...  2017-01-01     ec
# 10       https://open.spotify.com/track/3dQDid3IUNhZy1O...  2017-01-01     ec
# 11       https://open.spotify.com/track/20ZAJdsKB5IGbGj...  2017-01-01     ec
# 12       https://open.spotify.com/track/4pdPtRcBmOSQDlJ...  2017-01-01     ec
# 13       https://open.spotify.com/track/6YZdkObH88npeKr...  2017-01-01     ec
# 14       https://open.spotify.com/track/1lxswgIpzV6HhEN...  2017-01-01     ec
# 15       https://open.spotify.com/track/6DUdDIRgLqCGq1D...  2017-01-01     ec
# 16       https://open.spotify.com/track/1xznGGDReH1oQq0...  2017-01-01     ec
# 17       https://open.spotify.com/track/7BKLCZ1jbUBVqRi...  2017-01-01     ec
# 18       https://open.spotify.com/track/5aAx2yezTd8zXrk...  2017-01-01     ec
# 19       https://open.spotify.com/track/1pWYnQIlqxTh5bx...  2017-01-01     ec
# 20       https://open.spotify.com/track/5MFzQMkrl1FOOng...  2017-01-01     ec
# 21       https://open.spotify.com/track/0OMRAvrtLWE2Tvc...  2017-01-01     ec
# 22       https://open.spotify.com/track/6b8Be6ljOzmkOmF...  2017-01-01     ec
# 3441194  https://open.spotify.com/track/0pmGleExiQyd0Hx...  2018-01-09     hk
# 3441195  https://open.spotify.com/track/58SUsgamkW6vFFq...  2018-01-09     hk
# 3441196  https://open.spotify.com/track/2jyjhRf6DVbMPU5...  2018-01-09     hk
#
# [3441197 rows x 7 columns]

# %%
df = df.groupby(['Track Name', 'Artist']).sum()

# %%
df
# Out:
#                                                                        Position  \
# Track Name                                         Artist
# "All That Is or Ever Was or Ever Will Be"          Alan Silvestri           383
# "Read All About It, Pt. III"                       Emeli Sandé             2306
# #99                                                JVG                     1126
# #Askip                                             Black M                 3184
# #Biziz - feat. Lil Bege                            Reynmen                 4488
# #CTZK                                              Sir Mich               20515
# #Elämänpeli (feat. Touko)                          Mr. Elämänpeli          5545
# #HEY!                                              Pase Libre             11033
# #JM                                                Broederliefde           2747
# #JesuispasséchezSo EP 11                           Sofiane                  539
# #LDL                                               Niro                     289
# #Lávkóma                                           Kis Grófo               6124
# #Natural                                           Paty Cantú             65950
# #PTD                                               Dadju                   2396
# #SELFIE                                            The Chainsmokers         109
# #Sohavégetnemérős                                  Wellhello                152
# #SorryNotSorry - 3onderboy remix                   BANANALEMON              803
# #Totopirate                                        Hayce Lemsi              353
# #hashdark                                          Charisma.com             866
# #háttérzaj                                         Zävodi                   318
# #santaclara                                        Emily Roberts            177
# #愛                                                 A-Lin                    154
# &Run                                               Sir Sly                  181
# 'Till I Collapse                                   Eminem                552314
# (Don't Fear) The Reaper                            Blue Öyster Cult        1526
# (Everything I Do) I Do It For You                  Bryan Adams             1081
# (I Can't Get No) Satisfaction - Mono Version / ... The Rolling Stones       742
# (Intro) I'm so Grateful                            DJ Khaled                482
# (It Must've Been Ol') Santa Claus                  Harry Connick, Jr.       324
# (No One Knows Me) Like the Piano                   Sampha                  3401
# ...                                                                         ...
# 鼓聲若響                                               Chyi Chin                987
# 龍捲風                                                Jay Chou                 728
# 龍鬚糖                                                Hacken Lee               180
# 가을 아침 [Gaeul Achim] : Autumn morning               IU                       174
# 그리워요 Girlfriend                                    Henry                    124
# 기억을 걷는 밤 Walk On Memories                          EXO                     1510
# 긴 밤이 오면                                            Eddy Kim                5007
# 날개 Feel So Fine                                    TAEYEON                 2686
# 낮에 뜨는 별 Starlight                                  SUHO                     158
# 내가 미쳐 Going Crazy                                  EXO                     1414
# 너의 손짓 Touch It                                     EXO                     1402
# 다이아몬드 Diamond                                      EXO                     1743
# 러시안 룰렛 Russian Roulette                            Red Velvet              1350
# 마지막 첫사랑 My First and Last                          NCT DREAM                919
# 바람이 불면 When The Wind Blows                         YOONA                    350
# 바래다줄게 Take You Home                                BAEKHYUN                 492
# 부메랑 Boomerang                                      EXO                      259
# 불타오르네 FIRE                                         BTS                     7651
# 빨간 맛 Red Flavor                                    Red Velvet             37084
# 사랑 좀 하고 싶어 Real Love - Acoustic Version            Henry                    192
# 소름 Chill                                           EXO                     1175
# 수채화 Love in Color                                  TAEYEON                 1035
# 안녕 못해 I'm Not Okay (From “MISSING 9”)              CHEN                     189
# 에너제틱 Energetic                                     Wanna One                504
# 여름빛 Mojito                                         Red Velvet               188
# 전야 前夜 The Eve                                      EXO                    17063
# 지나갈 테니 Been Through                                EXO                     1180
# 쩔어 DOPE                                            BTS                     7545
# 피 땀 눈물                                             BTS                     2757
# 피카부 Peek-A-Boo                                     Red Velvet             24895
#
#                                                                          Streams
# Track Name                                         Artist
# "All That Is or Ever Was or Ever Will Be"          Alan Silvestri           7311
# "Read All About It, Pt. III"                       Emeli Sandé             57025
# #99                                                JVG                     31826
# #Askip                                             Black M                296862
# #Biziz - feat. Lil Bege                            Reynmen                403591
# #CTZK                                              Sir Mich               669563
# #Elämänpeli (feat. Touko)                          Mr. Elämänpeli         405771
# #HEY!                                              Pase Libre             109035
# #JM                                                Broederliefde         6756985
# #JesuispasséchezSo EP 11                           Sofiane                174907
# #LDL                                               Niro                    51922
# #Lávkóma                                           Kis Grófo               62550
# #Natural                                           Paty Cantú            8521151
# #PTD                                               Dadju                  676409
# #SELFIE                                            The Chainsmokers        18668
# #Sohavégetnemérős                                  Wellhello                1032
# #SorryNotSorry - 3onderboy remix                   BANANALEMON              7242
# #Totopirate                                        Hayce Lemsi             56854
# #hashdark                                          Charisma.com             6329
# #háttérzaj                                         Zävodi                   3741
# #santaclara                                        Emily Roberts            4273
# #愛                                                 A-Lin                    3218
# &Run                                               Sir Sly                  7759
# 'Till I Collapse                                   Eminem              133808040
# (Don't Fear) The Reaper                            Blue Öyster Cult      1404687
# (Everything I Do) I Do It For You                  Bryan Adams            151773
# (I Can't Get No) Satisfaction - Mono Version / ... The Rolling Stones     150228
# (Intro) I'm so Grateful                            DJ Khaled              277571
# (It Must've Been Ol') Santa Claus                  Harry Connick, Jr.     212567
# (No One Knows Me) Like the Piano                   Sampha                 731142
# ...                                                                          ...
# 鼓聲若響                                               Chyi Chin               24702
# 龍捲風                                                Jay Chou                 7829
# 龍鬚糖                                                Hacken Lee               2299
# 가을 아침 [Gaeul Achim] : Autumn morning               IU                       2966
# 그리워요 Girlfriend                                    Henry                    3497
# 기억을 걷는 밤 Walk On Memories                          EXO                    114086
# 긴 밤이 오면                                            Eddy Kim               106637
# 날개 Feel So Fine                                    TAEYEON                 84106
# 낮에 뜨는 별 Starlight                                  SUHO                     2824
# 내가 미쳐 Going Crazy                                  EXO                    101344
# 너의 손짓 Touch It                                     EXO                    120560
# 다이아몬드 Diamond                                      EXO                    152291
# 러시안 룰렛 Russian Roulette                            Red Velvet              20232
# 마지막 첫사랑 My First and Last                          NCT DREAM               26737
# 바람이 불면 When The Wind Blows                         YOONA                    5007
# 바래다줄게 Take You Home                                BAEKHYUN                16919
# 부메랑 Boomerang                                      EXO                     20567
# 불타오르네 FIRE                                         BTS                    184096
# 빨간 맛 Red Flavor                                    Red Velvet            1950750
# 사랑 좀 하고 싶어 Real Love - Acoustic Version            Henry                    2562
# 소름 Chill                                           EXO                    100259
# 수채화 Love in Color                                  TAEYEON                 23120
# 안녕 못해 I'm Not Okay (From “MISSING 9”)              CHEN                     2454
# 에너제틱 Energetic                                     Wanna One               19898
# 여름빛 Mojito                                         Red Velvet               5433
# 전야 前夜 The Eve                                      EXO                    976392
# 지나갈 테니 Been Through                                EXO                     87456
# 쩔어 DOPE                                            BTS                    209493
# 피 땀 눈물                                             BTS                     68673
# 피카부 Peek-A-Boo                                     Red Velvet            2078217
#
# [19922 rows x 2 columns]

# %%
df = df.sort_values(by='Streams', ascending=False)

# %%
df
# Out:
#                                                                           Position  \
# Track Name                                         Artist
# Shape of You                                       Ed Sheeran               301513
# Despacito - Remix                                  Luis Fonsi               477232
# Despacito (Featuring Daddy Yankee)                 Luis Fonsi               816152
# Something Just Like This                           The Chainsmokers         725122
# HUMBLE.                                            Kendrick Lamar           854060
# Unforgettable                                      French Montana           667424
# rockstar                                           Post Malone              127973
# I'm the One                                        DJ Khaled                548303
# It Ain't Me (with Selena Gomez)                    Kygo                     865603
# XO TOUR Llif3                                      Lil Uzi Vert             815686
# That's What I Like                                 Bruno Mars               904200
# New Rules                                          Dua Lipa                 238554
# I Don’t Wanna Live Forever (Fifty Shades Darker... ZAYN                    1076427
# Attention                                          Charlie Puth             560536
# Mi Gente                                           J Balvin                 328826
# Congratulations                                    Post Malone             1045037
# Thunder                                            Imagine Dragons          624701
# Havana                                             Camila Cabello           205274
# Stay (with Alessia Cara)                           Zedd                     752376
# Believer                                           Imagine Dragons         1124683
# Perfect                                            Ed Sheeran               897147
# Mask Off                                           Future                   743455
# Swalla (feat. Nicki Minaj & Ty Dolla $ign)         Jason Derulo             858898
# Paris                                              The Chainsmokers         854958
# There's Nothing Holdin' Me Back                    Shawn Mendes             734230
# Rockabye (feat. Sean Paul & Anne-Marie)            Clean Bandit            1156948
# Castle on the Hill                                 Ed Sheeran               889667
# Me Rehúso                                          Danny Ocean              431309
# Say You Won't Let Go                               James Arthur            1010946
# 1-800-273-8255                                     Logic                    640433
# ...                                                                            ...
# Fram á nótt                                        Nýdönsk                     123
# Como Te Gusta el Boliche                           Tu Papa                     188
# Satan Claus                                        Radikal Chef                 95
# Alright                                            Suchmos                     173
# Name For You                                       The Shins                   190
# Vērtības                                           Mesa                        101
# Ella y Yo (Remix) [feat. Farruko, Ozuna, Arcang... Pepe Quintana               166
# Nepočujem                                          Dame                         84
# Gangsta's Paradise                                 Coolio                      193
# HES un tu                                          Instrumenti                  69
# Join the Riot                                      Paddy And The Rats          188
# Adiós Melancolía - Acústico                        Ricardo Arjona              176
# Magnolijas rīts                                    Carnival Youth               65
# Forever Young                                      Lil Yachty                  112
# Sick Love                                          Red Hot Chili Peppers        69
# I'm A Fan (feat. Jeremih)                          Pia Mia                     193
# Rimas pa'seducir                                   Cultura Profética           106
# Ticot, mīlot un gaidot                             Zigfrīds Muktupāvels        148
# Zvani Un Sveces                                    Raimonds Pauls              150
# Kandino Patkani                                    Rytmus                      193
# Bailemos juntos                                    #TocoParaVos                197
# Que Locura Enamorarme De Ti                        Eddie Santiago              182
# Guwop (feat. Quavo, Offset and Young Scooter)      Young Thug                  106
# NO SCARED                                          ONE OK ROCK                  1003
# Hvað Finnst Þér Um Það? (feat. Kilo)               Ragga Holm                   1002
# Eső                                                Margaret Island              1002
# Hlavarozbitajakslovensko                           Radikal Chef                 1002
# Улети                                              T-Fest                       1002
# Ir Vērts                                           Singapūras Satīns            1002
# Mit Mondjak Még                                    Kowalsky Meg A Vega          1001
#
# [19922 rows x 2 columns]

# %%
df.head(10)
# Out:
#                                                      Position     Streams
# Track Name                         Artist
# Shape of You                       Ed Sheeran          301513  2993988783
# Despacito - Remix                  Luis Fonsi          477232  1829621841
# Despacito (Featuring Daddy Yankee) Luis Fonsi          816152  1460802540
# Something Just Like This           The Chainsmokers    725122  1386258295
# HUMBLE.                            Kendrick Lamar      854060  1311243745
# Unforgettable                      French Montana      667424  1289150890
# rockstar                           Post Malone         127973  1260181617
# I'm the One                        DJ Khaled           548303  1254196301
# It Ain't Me (with Selena Gomez)    Kygo                865603  1190339348
# XO TOUR Llif3                      Lil Uzi Vert        815686  1171827725

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#          Position                                  Track Name  \
# 0               1                  Reggaetón Lento (Bailemos)
# 1               2                                    Chantaje
# 2               3                   Otra Vez (feat. J Balvin)
# 3               4                                Vente Pa' Ca
# 4               5                                      Safari
# 5               6                                La Bicicleta
# 6               7                                  Ay Mi Dios
# 7               8                          Andas En Mi Cabeza
# 8               9                                 Traicionera
# 9              10                                 Shaky Shaky
# 10             11                                  Vacaciones
# 11             12                      Dile Que Tu Me Quieres
# 12             13                             Let Me Love You
# 13             14                            DUELE EL CORAZON
# 14             15                                     Chillax
# 15             16                              Borro Cassette
# 16             17                                   One Dance
# 17             18                                      Closer
# 18             19                                     Starboy
# 19             20                             Desde Esa Noche
# 20             21                            Don't Wanna Know
# 21             22                                 La Gozadera
# 22             23                                   24K Magic
# 23             24            Me Llamas (feat. Maluma) - Remix
# 24             25                                Cuatro Babys
# 25             26                                      My Way
# 26             27                     Gyal You A Party Animal
# 27             28                               Baila Conmigo
# 28             29             Gyal You A Party Animal - Remix
# 29             30  We Don't Talk Anymore (feat. Selena Gomez)
# ...           ...                                         ...
# 3441167       171                                        失落沙洲
# 3441168       172                                          晴天
# 3441169       173                                        Kong
# 3441170       174                             Congratulations
# 3441171       175                               There for You
# 3441172       176                               XO TOUR Llif3
# 3441173       177                                          草原
# 3441174       178                           Don't Let Me Down
# 3441175       179                                     只知感覺失了蹤
# 3441176       180                                        修煉愛情
# 3441177       181      Pretty Girl - Cheat Codes X CADE Remix
# 3441178       182                                          心淡
# 3441179       183                    Friends (with BloodPop®)
# 3441180       184                                        高山低谷
# 3441181       185                                        死亡之吻
# 3441182       186                                          無賴
# 3441183       187                                       月球下的人
# 3441184       188                                     Gashina
# 3441185       189                                          七友
# 3441186       190                                     那一年零一個月
# 3441187       191               我多喜歡你,你會知道 - 網劇《致我們單純的小美好》推廣曲
# 3441188       192                                        富士山下
# 3441189       193                               Unforgettable
# 3441190       194                          Castle on the Hill
# 3441191       195                           Whatever It Takes
# 3441192       196                          More Than You Know
# 3441193       197                                      Issues
# 3441194       198                                 Tuo Fei Lun
# 3441195       199                                          面具
# 3441196       200                                  Let Her Go
#
#                      Artist  Streams  \
# 0                      CNCO    19272
# 1                   Shakira    19270
# 2             Zion & Lennox    15761
# 3              Ricky Martin    14954
# 4                  J Balvin    14269
# 5              Carlos Vives    12843
# 6                  IAmChino    10986
# 7             Chino & Nacho    10653
# 8           Sebastian Yatra     9807
# 9              Daddy Yankee     9612
# 10                    Wisin     9611
# 11                    Ozuna     8982
# 12                 DJ Snake     8834
# 13         Enrique Iglesias     8309
# 14                  Farruko     7822
# 15                   Maluma     7586
# 16                    Drake     7472
# 17         The Chainsmokers     7416
# 18               The Weeknd     7006
# 19                   Thalía     6779
# 20                 Maroon 5     6582
# 21            Gente De Zona     6521
# 22               Bruno Mars     6261
# 23                  Piso 21     6237
# 24                   Maluma     6028
# 25            Calvin Harris     5723
# 26             Charly Black     5601
# 27               Juan Magán     5586
# 28             Charly Black     5541
# 29             Charlie Puth     5362
# ...                     ...      ...
# 3441167            LaLa Hsu     2381
# 3441168            Jay Chou     2347
# 3441169           Justin Lo     2331
# 3441170         Post Malone     2309
# 3441171       Martin Garrix     2304
# 3441172        Lil Uzi Vert     2295
# 3441173            Phil Lam     2286
# 3441174    The Chainsmokers     2277
# 3441175           Dear Jane     2272
# 3441176              JJ Lin     2255
# 3441177    Maggie Lindemann     2251
# 3441178           Joey Yung     2248
# 3441179       Justin Bieber     2223
# 3441180            Phil Lam     2220
# 3441181         Kelvin Kwan     2219
# 3441182        Ronald Cheng     2204
# 3441183             Gin Lee     2176
# 3441184               SUNMI     2171
# 3441185        Edmond Leung     2166
# 3441186         Feanna Wong     2165
# 3441187                 王俊琪     2148
# 3441188          Eason Chan     2144
# 3441189      French Montana     2134
# 3441190          Ed Sheeran     2134
# 3441191     Imagine Dragons     2130
# 3441192  Axwell /\ Ingrosso     2126
# 3441193      Julia Michaels     2117
# 3441194          Eason Chan     2112
# 3441195          Alfred Hui     2102
# 3441196           Passenger     2088
#
#                                                        URL        Date Region
# 0        https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01     ec
# 1        https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01     ec
# 2        https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01     ec
# 3        https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01     ec
# 4        https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01     ec
# 5        https://open.spotify.com/track/0sXvAOmXgjR2QUq...  2017-01-01     ec
# 6        https://open.spotify.com/track/6stYbAJgTszHAHZ...  2017-01-01     ec
# 7        https://open.spotify.com/track/5mey7CLLuFToM2P...  2017-01-01     ec
# 8        https://open.spotify.com/track/5J1c3M4EldCfNxX...  2017-01-01     ec
# 9        https://open.spotify.com/track/58IL315gMSTD37D...  2017-01-01     ec
# 10       https://open.spotify.com/track/3dQDid3IUNhZy1O...  2017-01-01     ec
# 齊晨                      359        5291
# 龔詩嘉                     121        5185
#
# [6628 rows x 2 columns]

# %%
df = df.sort_values(by='Streams', ascending=False)

# %%
df
# Out:
#                                         Position     Streams
# Artist
# Ed Sheeran                              10534351  8913973976
# Drake                                    4679189  4523630992
# The Chainsmokers                         5304084  4292590087
# Post Malone                              2466648  3700404149
# Kendrick Lamar                           2471880  3570665303
# Luis Fonsi                               1442101  3555514919
# J Balvin                                 1986826  2494735971
# Calvin Harris                            3110608  2397708371
# Imagine Dragons                          2727838  2322921399
# DJ Khaled                                1171546  2236224259
# The Weeknd                               3062794  2225144099
# Clean Bandit                             2040760  2058671109
# ZAYN                                     1923886  2018633468
# Kygo                                     2229490  2016877886
# Bruno Mars                               2982195  1915554926
# Lil Uzi Vert                             1279812  1903703272
# Martin Garrix                            2735015  1866707135
# Charlie Puth                             2403270  1815408456
# Maroon 5                                 2379138  1770872697
# Migos                                    1309456  1769224015
# Shawn Mendes                             3150049  1745850599
# Camila Cabello                           1237220  1704460390
# Future                                   1410489  1658173720
# Major Lazer                              3401353  1489305687
# Khalid                                   1238272  1459421592
# French Montana                            778066  1311955901
# XXXTENTACION                             1326905  1264164963
# Dua Lipa                                  820795  1247738973
# Maluma                                   2170507  1233640551
# Jason Derulo                             1253659  1224859742
# ...                                          ...         ...
# EGO                                          107        1066
# Miramor                                      177        1066
# Jumis                                         57        1057
# RuPaul                                        95        1056
# Sylvia Erla                                  105        1053
# Á Móti Sól                                   112        1052
# Huntar                                       189        1049
# KanoeRana                                    151        1048
# Kamille                                      198        1047
# la Pandilla Rd                               143        1046
# Aventura                                     174        1046
# Alex Bueno                                   193        1044
# XINDL X                                      184        1037
# Sergio Vargas                                196        1028
# David Kada                                   197        1027
# Reggaetones                                  185        1026
# Lubomír Lipský                               149        1025
# Edwin Luna y La Trakalosa de Monterrey       121        1025
# Metsakutsu                                    67        1024
# Helena Vondráčková                           150        1023
# Miroslav Zbirka                              152        1019
# Danny Blue and the Old Socks                  53        1017
# The Shins                                    190        1013
# Mesa                                         101        1012
# Paddy And The Rats                           188        1009
# Pia Mia                                      193        1007
# Zigfrīds Muktupāvels                         148        1006
# Eddie Santiago                               182        1005
# T-Fest                                        56        1002
# Ragga Holm                                   121        1002
#
# [6628 rows x 2 columns]

# %%
df = df.head(10)

# %%
df
# Out:
#                   Position     Streams
# Artist
# Ed Sheeran        10534351  8913973976
# Drake              4679189  4523630992
# The Chainsmokers   5304084  4292590087
# Post Malone        2466648  3700404149
# Kendrick Lamar     2471880  3570665303
# Luis Fonsi         1442101  3555514919
# J Balvin           1986826  2494735971
# Calvin Harris      3110608  2397708371
# Imagine Dragons    2727838  2322921399
# DJ Khaled          1171546  2236224259

# %%
df
# Out:
#                   Position     Streams
# Artist
# Ed Sheeran        10534351  8913973976
# Drake              4679189  4523630992
# The Chainsmokers   5304084  4292590087
# Post Malone        2466648  3700404149
# Kendrick Lamar     2471880  3570665303
# Luis Fonsi         1442101  3555514919
# J Balvin           1986826  2494735971
# Calvin Harris      3110608  2397708371
# Imagine Dragons    2727838  2322921399
# DJ Khaled          1171546  2236224259

# %%
df
# Out:
#                   Position     Streams
# Artist
# Ed Sheeran        10534351  8913973976
# Drake              4679189  4523630992
# The Chainsmokers   5304084  4292590087
# Post Malone        2466648  3700404149
# Kendrick Lamar     2471880  3570665303
# Luis Fonsi         1442101  3555514919
# J Balvin           1986826  2494735971
# Calvin Harris      3110608  2397708371
# Imagine Dragons    2727838  2322921399
# DJ Khaled          1171546  2236224259

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#          Position                                  Track Name  \
# 0               1                  Reggaetón Lento (Bailemos)
# 1               2                                    Chantaje
# 2               3                   Otra Vez (feat. J Balvin)
# 3               4                                Vente Pa' Ca
# 4               5                                      Safari
# 5               6                                La Bicicleta
# 6               7                                  Ay Mi Dios
# 7               8                          Andas En Mi Cabeza
# 8               9                                 Traicionera
# 9              10                                 Shaky Shaky
# 10             11                                  Vacaciones
# 11             12                      Dile Que Tu Me Quieres
# 12             13                             Let Me Love You
# 13             14                            DUELE EL CORAZON
# 14             15                                     Chillax
# 15             16                              Borro Cassette
# 16             17                                   One Dance
# 17             18                                      Closer
# 18             19                                     Starboy
# 19             20                             Desde Esa Noche
# 20             21                            Don't Wanna Know
# 21             22                                 La Gozadera
# 22             23                                   24K Magic
# 23             24            Me Llamas (feat. Maluma) - Remix
# 24             25                                Cuatro Babys
# 25             26                                      My Way
# 26             27                     Gyal You A Party Animal
# 27             28                               Baila Conmigo
# 28             29             Gyal You A Party Animal - Remix
# 29             30  We Don't Talk Anymore (feat. Selena Gomez)
# ...           ...                                         ...
# 3441167       171                                        失落沙洲
# 3441168       172                                          晴天
# 3441169       173                                        Kong
# 3441170       174                             Congratulations
# 3441171       175                               There for You
# 3441172       176                               XO TOUR Llif3
# 3441173       177                                          草原
# 3441174       178                           Don't Let Me Down
# 3441175       179                                     只知感覺失了蹤
# 3441176       180                                        修煉愛情
# 3441177       181      Pretty Girl - Cheat Codes X CADE Remix
# 3441178       182                                          心淡
# 3441179       183                    Friends (with BloodPop®)
# 3441180       184                                        高山低谷
# 3441181       185                                        死亡之吻
# 3441182       186                                          無賴
# 3441183       187                                       月球下的人
# 3441184       188                                     Gashina
# 3441185       189                                          七友
# 3441186       190                                     那一年零一個月
# 3441187       191               我多喜歡你,你會知道 - 網劇《致我們單純的小美好》推廣曲
# 3441188       192                                        富士山下
# 3441189       193                               Unforgettable
# 3441190       194                          Castle on the Hill
# 3441191       195                           Whatever It Takes
# 3441192       196                          More Than You Know
# 3441193       197                                      Issues
# 3441194       198                                 Tuo Fei Lun
# 3441195       199                                          面具
# 3441196       200                                  Let Her Go
#
#                      Artist  Streams  \
# 0                      CNCO    19272
# 1                   Shakira    19270
# 2             Zion & Lennox    15761
# 3              Ricky Martin    14954
# 4                  J Balvin    14269
# 5              Carlos Vives    12843
# 6                  IAmChino    10986
# 7             Chino & Nacho    10653
# 8           Sebastian Yatra     9807
# 9              Daddy Yankee     9612
# 10                    Wisin     9611
# 11                    Ozuna     8982
# 12                 DJ Snake     8834
# 13         Enrique Iglesias     8309
# 14                  Farruko     7822
# 15                   Maluma     7586
# 16                    Drake     7472
# 17         The Chainsmokers     7416
# 18               The Weeknd     7006
# 19                   Thalía     6779
# 20                 Maroon 5     6582
# 21            Gente De Zona     6521
# 22               Bruno Mars     6261
# 23                  Piso 21     6237
# 24                   Maluma     6028
# 25            Calvin Harris     5723
# 26             Charly Black     5601
# 27               Juan Magán     5586
# 28             Charly Black     5541
# 29             Charlie Puth     5362
# ...                     ...      ...
# 3441167            LaLa Hsu     2381
# 3441168            Jay Chou     2347
# 3441169           Justin Lo     2331
# 3441170         Post Malone     2309
# 3441171       Martin Garrix     2304
# 3441172        Lil Uzi Vert     2295
# 3441173            Phil Lam     2286
# 3441174    The Chainsmokers     2277
# 3441175           Dear Jane     2272
# 3441176              JJ Lin     2255
# 3441177    Maggie Lindemann     2251
# 3441178           Joey Yung     2248
# 3441179       Justin Bieber     2223
# 3441180            Phil Lam     2220
# 3441181         Kelvin Kwan     2219
# 3441182        Ronald Cheng     2204
# 3441183             Gin Lee     2176
# 3441184               SUNMI     2171
# 3441185        Edmond Leung     2166
# 3441186         Feanna Wong     2165
# 3441187                 王俊琪     2148
# 3441188          Eason Chan     2144
# 3441189      French Montana     2134
# 3441190          Ed Sheeran     2134
# 3441191     Imagine Dragons     2130
# 3441192  Axwell /\ Ingrosso     2126
# 3441193      Julia Michaels     2117
# 3441194          Eason Chan     2112
# 3441195          Alfred Hui     2102
# 3441196           Passenger     2088
#
#                                                        URL        Date Region
# 0        https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01     ec
# 1        https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01     ec
# 2        https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01     ec
# 3        https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01     ec
# 4        https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01     ec
# 5        https://open.spotify.com/track/0sXvAOmXgjR2QUq...  2017-01-01     ec
# 6        https://open.spotify.com/track/6stYbAJgTszHAHZ...  2017-01-01     ec
# 7        https://open.spotify.com/track/5mey7CLLuFToM2P...  2017-01-01     ec
# 8        https://open.spotify.com/track/5J1c3M4EldCfNxX...  2017-01-01     ec
# 9        https://open.spotify.com/track/58IL315gMSTD37D...  2017-01-01     ec
# 10       https://open.spotify.com/track/3dQDid3IUNhZy1O...  2017-01-01     ec
# 11       https://open.spotify.com/track/20ZAJdsKB5IGbGj...  2017-01-01     ec
# 12       https://open.spotify.com/track/4pdPtRcBmOSQDlJ...  2017-01-01     ec
# 13       https://open.spotify.com/track/6YZdkObH88npeKr...  2017-01-01     ec
# 14       https://open.spotify.com/track/1lxswgIpzV6HhEN...  2017-01-01     ec
# 15       https://open.spotify.com/track/6DUdDIRgLqCGq1D...  2017-01-01     ec
# 16       https://open.spotify.com/track/1xznGGDReH1oQq0...  2017-01-01     ec
# 3441189  https://open.spotify.com/track/3B54sVLJ402zGa6...  2018-01-09     hk
# 3441190  https://open.spotify.com/track/6PCUP3dWmTjcTtX...  2018-01-09     hk
# 3441191  https://open.spotify.com/track/4IWAyPf1KMq7JCy...  2018-01-09     hk
# 3441192  https://open.spotify.com/track/71bBFbfn2OBK5Qw...  2018-01-09     hk
# 3441193  https://open.spotify.com/track/7vu0JkJh0ldukEY...  2018-01-09     hk
# 3441194  https://open.spotify.com/track/0pmGleExiQyd0Hx...  2018-01-09     hk
# 3441195  https://open.spotify.com/track/58SUsgamkW6vFFq...  2018-01-09     hk
# 3441196  https://open.spotify.com/track/2jyjhRf6DVbMPU5...  2018-01-09     hk
#
# [3441197 rows x 7 columns]

# %%
artist = df.groupby(['Artist']).sum()

# %%
artist
# Out:
#                    Position     Streams
# Artist
# #TocoParaVos         101278     3485730
# $uicideBoy$            1257       44258
# *NSYNC                14228     7484201
# -M-                     147       43037
# 070 Shake               547       31035
# 100%                    188        2465
# 101Barz                 690       81269
# 10cm                  12711      247144
# 12:00                   560        6706
# 13 Block               2836      853726
# 13 Crowns               622        8652
# 16yrold                2113      235239
# 187 Strassenbande    182088    88355831
# 1987                    161       23914
# 1Kilo                 46247    74279422
# 2 Chainz             201213   358556483
# 21 Savage            825054  1127824035
# 22 Savage              4513    12126721
# 24Heavy                 294        7525
# 257ers                34159     6365229
# 2NE1                   5097      118844
# 2Pac                    756      716046
# 3 Doors Down            371        6518
# 30Y                    4138       28905
# 3robi                 21281     5764078
# 4 Non Blondes           638       61852
# 4Keus Gang            11463     3699534
# 5 After Midnight      11359     3172245
# 50 Cent                4419      848913
# 53A                      80        7124
# ...                     ...         ...
# 阿達                     5845      193172
# 陳以桐                   41483      988144
# 陳嘉唯                    5837      121959
# 陳念澤                     360       10340
# 陳思函                    2014       44394
# 陳惠婷                    1063       30678
# 陳李張王                    156        2853
# 陳毓芸                     199        3825
# 陳洛                      327       11035
# 陳潔儀                    1345       56703
# 陶晶瑩                    3565       58375
# 雀斑                      206        8235
# 順子                     1242       27838
# 顏力妃                    1104       19114
# 馬雲                     1272       43124
# 魯向卉                     833       18751
# 黃小楨                     161        3509
# 黃小琥                    1216       23952
# 黃渤                      581       14237
# 黃湘怡                     347        5169
# 黃玠                     4369      165980
# 黃立行                     150        3020
# 黃維德                     134        3188
# 黃義達                     734       20702
# 黃聖萊Lex                  424       11070
# 黃荻鈞                     179        7733
# 黄靖伦                     790       13319
# 鼓鼓                     5397      103230
# 齊晨                      359        5291
# 龔詩嘉                     121        5185
#
# [6628 rows x 2 columns]

# %%
artist = artist.sort_values(by='Streams', ascending=False)

# %%
artist
# Out:
#                                         Position     Streams
# Artist
# Ed Sheeran                              10534351  8913973976
# Drake                                    4679189  4523630992
# The Chainsmokers                         5304084  4292590087
# Post Malone                              2466648  3700404149
# Kendrick Lamar                           2471880  3570665303
# Luis Fonsi                               1442101  3555514919
# J Balvin                                 1986826  2494735971
# Calvin Harris                            3110608  2397708371
# Imagine Dragons                          2727838  2322921399
# DJ Khaled                                1171546  2236224259
# The Weeknd                               3062794  2225144099
# Clean Bandit                             2040760  2058671109
# ZAYN                                     1923886  2018633468
# Kygo                                     2229490  2016877886
# Bruno Mars                               2982195  1915554926
# Lil Uzi Vert                             1279812  1903703272
# Martin Garrix                            2735015  1866707135
# Charlie Puth                             2403270  1815408456
# Maroon 5                                 2379138  1770872697
# Migos                                    1309456  1769224015
# Shawn Mendes                             3150049  1745850599
# Camila Cabello                           1237220  1704460390
# Future                                   1410489  1658173720
# Major Lazer                              3401353  1489305687
# Khalid                                   1238272  1459421592
# French Montana                            778066  1311955901
# XXXTENTACION                             1326905  1264164963
# Dua Lipa                                  820795  1247738973
# Maluma                                   2170507  1233640551
# Jason Derulo                             1253659  1224859742
# ...                                          ...         ...
# EGO                                          107        1066
# Miramor                                      177        1066
# Jumis                                         57        1057
# RuPaul                                        95        1056
# Sylvia Erla                                  105        1053
# Á Móti Sól                                   112        1052
# Huntar                                       189        1049
# KanoeRana                                    151        1048
# Kamille                                      198        1047
# la Pandilla Rd                               143        1046
# Aventura                                     174        1046
# Alex Bueno                                   193        1044
# XINDL X                                      184        1037
# Sergio Vargas                                196        1028
# David Kada                                   197        1027
# Reggaetones                                  185        1026
# Lubomír Lipský                               149        1025
# Edwin Luna y La Trakalosa de Monterrey       121        1025
# Metsakutsu                                    67        1024
# Helena Vondráčková                           150        1023
# Miroslav Zbirka                              152        1019
# Danny Blue and the Old Socks                  53        1017
# The Shins                                    190        1013
# Mesa                                         101        1012
# Paddy And The Rats                           188        1009
# Pia Mia                                      193        1007
# Zigfrīds Muktupāvels                         148        1006
# Eddie Santiago                               182        1005
# T-Fest                                        56        1002
# Ragga Holm                                   121        1002
#
# [6628 rows x 2 columns]

# %%
print artist['Artist']
# Out:
#   File "<ipython-input-28-ea725238ee43>", line 1
#     print artist['Artist']
#                ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(artist['Artist'])?

# %%
artist
# Out:
#                                         Position     Streams
# Artist
# Ed Sheeran                              10534351  8913973976
# Drake                                    4679189  4523630992
# The Chainsmokers                         5304084  4292590087
# Post Malone                              2466648  3700404149
# Kendrick Lamar                           2471880  3570665303
# Luis Fonsi                               1442101  3555514919
# J Balvin                                 1986826  2494735971
# Calvin Harris                            3110608  2397708371
# Imagine Dragons                          2727838  2322921399
# DJ Khaled                                1171546  2236224259
# The Weeknd                               3062794  2225144099
# Clean Bandit                             2040760  2058671109
# ZAYN                                     1923886  2018633468
# Kygo                                     2229490  2016877886
# Bruno Mars                               2982195  1915554926
# Lil Uzi Vert                             1279812  1903703272
# Martin Garrix                            2735015  1866707135
# Charlie Puth                             2403270  1815408456
# Maroon 5                                 2379138  1770872697
# Migos                                    1309456  1769224015
# Shawn Mendes                             3150049  1745850599
# Camila Cabello                           1237220  1704460390
# Future                                   1410489  1658173720
# Major Lazer                              3401353  1489305687
# Khalid                                   1238272  1459421592
# French Montana                            778066  1311955901
# XXXTENTACION                             1326905  1264164963
# Dua Lipa                                  820795  1247738973
# Maluma                                   2170507  1233640551
# Jason Derulo                             1253659  1224859742
# ...                                          ...         ...
# EGO                                          107        1066
# Miramor                                      177        1066
# Jumis                                         57        1057
# RuPaul                                        95        1056
# Sylvia Erla                                  105        1053
# Á Móti Sól                                   112        1052
# Huntar                                       189        1049
# KanoeRana                                    151        1048
# Kamille                                      198        1047
# la Pandilla Rd                               143        1046
# Aventura                                     174        1046
# Alex Bueno                                   193        1044
# XINDL X                                      184        1037
# Sergio Vargas                                196        1028
# David Kada                                   197        1027
# Reggaetones                                  185        1026
# Lubomír Lipský                               149        1025
# Edwin Luna y La Trakalosa de Monterrey       121        1025
# Metsakutsu                                    67        1024
# Helena Vondráčková                           150        1023
# Miroslav Zbirka                              152        1019
# Danny Blue and the Old Socks                  53        1017
# The Shins                                    190        1013
# Mesa                                         101        1012
# Paddy And The Rats                           188        1009
# Pia Mia                                      193        1007
# Zigfrīds Muktupāvels                         148        1006
# Eddie Santiago                               182        1005
# T-Fest                                        56        1002
# Ragga Holm                                   121        1002
#
# [6628 rows x 2 columns]

# %%
artist [['Artist']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-01a8556287e3> in <module>()
# ----> 1 artist [['Artist']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['Artist'] not in index"

# %%
artist['Streams']
# Out:
# Artist
# Ed Sheeran                                8913973976
# Drake                                     4523630992
# The Chainsmokers                          4292590087
# Post Malone                               3700404149
# Kendrick Lamar                            3570665303
# Luis Fonsi                                3555514919
# J Balvin                                  2494735971
# Calvin Harris                             2397708371
# Imagine Dragons                           2322921399
# DJ Khaled                                 2236224259
# The Weeknd                                2225144099
# Clean Bandit                              2058671109
# ZAYN                                      2018633468
# Kygo                                      2016877886
# Bruno Mars                                1915554926
# Lil Uzi Vert                              1903703272
# Martin Garrix                             1866707135
# Charlie Puth                              1815408456
# Maroon 5                                  1770872697
# Migos                                     1769224015
# Shawn Mendes                              1745850599
# Camila Cabello                            1704460390
# Future                                    1658173720
# Major Lazer                               1489305687
# Khalid                                    1459421592
# French Montana                            1311955901
# XXXTENTACION                              1264164963
# Dua Lipa                                  1247738973
# Maluma                                    1233640551
# Jason Derulo                              1224859742
#                                              ...
# EGO                                             1066
# Miramor                                         1066
# Jumis                                           1057
# RuPaul                                          1056
# Sylvia Erla                                     1053
# Á Móti Sól                                      1052
# Huntar                                          1049
# KanoeRana                                       1048
# Kamille                                         1047
# la Pandilla Rd                                  1046
# Aventura                                        1046
# Alex Bueno                                      1044
# XINDL X                                         1037
# Sergio Vargas                                   1028
# David Kada                                      1027
# Reggaetones                                     1026
# Lubomír Lipský                                  1025
# Edwin Luna y La Trakalosa de Monterrey          1025
# Metsakutsu                                      1024
# Helena Vondráčková                              1023
# Miroslav Zbirka                                 1019
# Danny Blue and the Old Socks                    1017
# The Shins                                       1013
# Mesa                                            1012
# Paddy And The Rats                              1009
# Pia Mia                                         1007
# Zigfrīds Muktupāvels                            1006
# Eddie Santiago                                  1005
# T-Fest                                          1002
# Ragga Holm                                      1002
# Name: Streams, Length: 6628, dtype: int64

# %%
artistTop10 = artist.head(10)

# %%
artistTop10
# Out:
#                   Position     Streams
# Artist
# Ed Sheeran        10534351  8913973976
# Drake              4679189  4523630992
# The Chainsmokers   5304084  4292590087
# Post Malone        2466648  3700404149
# Kendrick Lamar     2471880  3570665303
# Luis Fonsi         1442101  3555514919
# J Balvin           1986826  2494735971
# Calvin Harris      3110608  2397708371
# Imagine Dragons    2727838  2322921399
# DJ Khaled          1171546  2236224259

# %%
artistTop10.index
# Out:
# Index(['Ed Sheeran', 'Drake', 'The Chainsmokers', 'Post Malone',
#        'Kendrick Lamar', 'Luis Fonsi', 'J Balvin', 'Calvin Harris',
#        'Imagine Dragons', 'DJ Khaled'],
#       dtype='object', name='Artist')

# %%
artistTop10 = artistTo10.index.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-674fafb37cf6> in <module>()
# ----> 1 artistTop10 = artistTo10.index.tolist()
#
# NameError: name 'artistTo10' is not defined

# %%
artistTop10 = artistTop10.index.tolist()

# %%
artistTop10
# Out:
# ['Ed Sheeran',
#  'Drake',
#  'The Chainsmokers',
#  'Post Malone',
#  'Kendrick Lamar',
#  'Luis Fonsi',
#  'J Balvin',
#  'Calvin Harris',
#  'Imagine Dragons',
#  'DJ Khaled']

# %%
df = df['Artist', 'Track Name', 'Streams']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Artist', 'Track Name', 'Streams')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-9e5a6f836327> in <module>()
# ----> 1 df = df['Artist', 'Track Name', 'Streams']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Artist', 'Track Name', 'Streams')

# %%
df = df[['Artist', 'Track Name', 'Streams']]

# %%
df
# Out:
#                      Artist                                  Track Name  \
# 0                      CNCO                  Reggaetón Lento (Bailemos)
# 1                   Shakira                                    Chantaje
# 2             Zion & Lennox                   Otra Vez (feat. J Balvin)
# 3              Ricky Martin                                Vente Pa' Ca
# 4                  J Balvin                                      Safari
# 5              Carlos Vives                                La Bicicleta
# 6                  IAmChino                                  Ay Mi Dios
# 7             Chino & Nacho                          Andas En Mi Cabeza
# 8           Sebastian Yatra                                 Traicionera
# 9              Daddy Yankee                                 Shaky Shaky
# 10                    Wisin                                  Vacaciones
# 11                    Ozuna                      Dile Que Tu Me Quieres
# 12                 DJ Snake                             Let Me Love You
# 13         Enrique Iglesias                            DUELE EL CORAZON
# 14                  Farruko                                     Chillax
# 15                   Maluma                              Borro Cassette
# 16                    Drake                                   One Dance
# 17         The Chainsmokers                                      Closer
# 18               The Weeknd                                     Starboy
# 19                   Thalía                             Desde Esa Noche
# 20                 Maroon 5                            Don't Wanna Know
# 21            Gente De Zona                                 La Gozadera
# 22               Bruno Mars                                   24K Magic
# 23                  Piso 21            Me Llamas (feat. Maluma) - Remix
# 24                   Maluma                                Cuatro Babys
# 25            Calvin Harris                                      My Way
# 26             Charly Black                     Gyal You A Party Animal
# 27               Juan Magán                               Baila Conmigo
# 28             Charly Black             Gyal You A Party Animal - Remix
# 29             Charlie Puth  We Don't Talk Anymore (feat. Selena Gomez)
# ...                     ...                                         ...
# 3441167            LaLa Hsu                                        失落沙洲
# 3441168            Jay Chou                                          晴天
# 3441169           Justin Lo                                        Kong
# 3441170         Post Malone                             Congratulations
# 3441171       Martin Garrix                               There for You
# 3441172        Lil Uzi Vert                               XO TOUR Llif3
# 3441173            Phil Lam                                          草原
# 3441174    The Chainsmokers                           Don't Let Me Down
# 3441175           Dear Jane                                     只知感覺失了蹤
# 3441176              JJ Lin                                        修煉愛情
# 3441177    Maggie Lindemann      Pretty Girl - Cheat Codes X CADE Remix
# 3441178           Joey Yung                                          心淡
# 3441179       Justin Bieber                    Friends (with BloodPop®)
# 3441180            Phil Lam                                        高山低谷
# 3441181         Kelvin Kwan                                        死亡之吻
# 3441182        Ronald Cheng                                          無賴
# 3441183             Gin Lee                                       月球下的人
# 3441184               SUNMI                                     Gashina
# 3441185        Edmond Leung                                          七友
# 3441186         Feanna Wong                                     那一年零一個月
# 3441187                 王俊琪               我多喜歡你,你會知道 - 網劇《致我們單純的小美好》推廣曲
# 3441188          Eason Chan                                        富士山下
# 3441189      French Montana                               Unforgettable
# 3441190          Ed Sheeran                          Castle on the Hill
# 3441191     Imagine Dragons                           Whatever It Takes
# 3441192  Axwell /\ Ingrosso                          More Than You Know
# 3441193      Julia Michaels                                      Issues
# 3441194          Eason Chan                                 Tuo Fei Lun
# 3441195          Alfred Hui                                          面具
# 3441196           Passenger                                  Let Her Go
#
#          Streams
# 0          19272
# 1          19270
# 2          15761
# 3          14954
# 4          14269
# 5          12843
# 6          10986
# 7          10653
# 8           9807
# 9           9612
# 10          9611
# 11          8982
# 12          8834
# 13          8309
# 14          7822
# 15          7586
# 16          7472
# 17          7416
# 18          7006
# 19          6779
# 20          6582
# 21          6521
# 22          6261
# 23          6237
# 24          6028
# 25          5723
# 26          5601
# 27          5586
# 28          5541
# 29          5362
# ...          ...
# 3441167     2381
# 3441168     2347
# 3441169     2331
# 3441170     2309
# 3441171     2304
# 3441172     2295
# 3441173     2286
# 3441174     2277
# 3441175     2272
# 3441176     2255
# 3441177     2251
# 3441178     2248
# 3441179     2223
# 3441180     2220
# 3441181     2219
# 3441182     2204
# 3441183     2176
# 3441184     2171
# 3441185     2166
# 3441186     2165
# 3441187     2148
# 3441188     2144
# 3441189     2134
# 3441190     2134
# 3441191     2130
# 3441192     2126
# 3441193     2117
# 3441194     2112
# 3441195     2102
# 3441196     2088
#
# [3441197 rows x 3 columns]

# %%
result = []
for name in artistTop10:
    for index, row in df.iterrows():
        if row[0] == name:
            result.append(row[0], row[1], row[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-06f35eebe8c1> in <module>()
#       3     for index, row in df.iterrows():
#       4         if row[0] == name:
# ----> 5             result.append(row[0], row[1], row[2])
#
# TypeError: append() takes exactly one argument (3 given)

# %%
result = []
for name in artistTop10:
    for index, row in df.iterrows():
        if row[0] == name:
            result.append([row[0], row[1], row[2]])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-6677d1063142> in <module>()
#       1 result = []
#       2 for name in artistTop10:
# ----> 3     for index, row in df.iterrows():
#       4         if row[0] == name:
#       5             result.append([row[0], row[1], row[2]])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in iterrows(self)
#     746         klass = self._constructor_sliced
#     747         for k, v in zip(self.index, self.values):
# --> 748             s = klass(v, index=columns, name=k)
#     749             yield k, s
#     750
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262             else:
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#     266                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3193             subarr = _sanitize_index(data, index, copy=True)
#    3194         else:
# -> 3195             subarr = _try_cast(data, True)
#    3196
#    3197         if copy:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _try_cast(arr, take_fast_path)
#    3159
#    3160         try:
# -> 3161             subarr = maybe_cast_to_datetime(arr, dtype)
#    3162             if not is_extension_type(subarr):
#    3163                 subarr = np.array(subarr, dtype=dtype, copy=copy)
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in maybe_cast_to_datetime(value, dtype, errors)
#    1042         elif not (is_array and not (issubclass(value.dtype.type, np.integer) or
#    1043                                     value.dtype == np.object_)):
# -> 1044             value = maybe_infer_to_datetimelike(value)
#    1045
#    1046     return value
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in maybe_infer_to_datetimelike(value, convert_dates)
#     867
#     868     # we only care about object dtypes
# --> 869     if not is_object_dtype(v):
#     870         return value
#     871
#
# KeyboardInterrupt:

# %%
result = []
for name in artistTop10:
    for index, row in df.iterrows():
        if row[0] == name:
            result.append([row[0], row[1], row[2]])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-6677d1063142> in <module>()
#       1 result = []
#       2 for name in artistTop10:
# ----> 3     for index, row in df.iterrows():
#       4         if row[0] == name:
#       5             result.append([row[0], row[1], row[2]])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in iterrows(self)
#     746         klass = self._constructor_sliced
#     747         for k, v in zip(self.index, self.values):
# --> 748             s = klass(v, index=columns, name=k)
#     749             yield k, s
#     750
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262             else:
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#     266                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3193             subarr = _sanitize_index(data, index, copy=True)
#    3194         else:
# -> 3195             subarr = _try_cast(data, True)
#    3196
#    3197         if copy:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _try_cast(arr, take_fast_path)
#    3159
#    3160         try:
# -> 3161             subarr = maybe_cast_to_datetime(arr, dtype)
#    3162             if not is_extension_type(subarr):
#    3163                 subarr = np.array(subarr, dtype=dtype, copy=copy)
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in maybe_cast_to_datetime(value, dtype, errors)
#    1042         elif not (is_array and not (issubclass(value.dtype.type, np.integer) or
#    1043                                     value.dtype == np.object_)):
# -> 1044             value = maybe_infer_to_datetimelike(value)
#    1045
#    1046     return value
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in maybe_infer_to_datetimelike(value, convert_dates)
#     854     """
#     855
# --> 856     if isinstance(value, (ABCDatetimeIndex, ABCPeriodIndex)):
#     857         return value
#     858     elif isinstance(value, ABCSeries):
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\generic.py in _check(cls, inst)
#       7     @classmethod
#       8     def _check(cls, inst):
# ----> 9         return getattr(inst, attr, '_typ') in comp
#      10
#      11     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:

# %%
df_result = df[df['Artist'].isin(artistTop10)]

# %%
artistTop10
# Out:
# ['Ed Sheeran',
#  'Drake',
#  'The Chainsmokers',
#  'Post Malone',
#  'Kendrick Lamar',
#  'Luis Fonsi',
#  'J Balvin',
#  'Calvin Harris',
#  'Imagine Dragons',
#  'DJ Khaled']

# %%
df_result
# Out:
#                    Artist                           Track Name  Streams
# 4                J Balvin                               Safari    14269
# 16                  Drake                            One Dance     7472
# 17       The Chainsmokers                               Closer     7416
# 25          Calvin Harris                               My Way     5723
# 36               J Balvin                                 Bobo     4781
# 39       The Chainsmokers                    Don't Let Me Down     4379
# 57               J Balvin                                Ginza     3005
# 62          Calvin Harris            This Is What You Came For     2860
# 105            Ed Sheeran                           Photograph     1981
# 116            Ed Sheeran                    Thinking Out Loud     1812
# 140      The Chainsmokers                          All We Know     1559
# 149                 Drake                             Too Good     1461
# 165                 Drake                            Fake Love     1377
# 175              J Balvin                   Pierde Los Modales     1324
# 189              J Balvin                             Ay Vamos     1264
# 194         Calvin Harris                How Deep Is Your Love     1237
# 203              J Balvin                               Safari    11958
# 210      The Chainsmokers                               Closer     8075
# 213                 Drake                            One Dance     7437
# 221         Calvin Harris                               My Way     6032
# 231      The Chainsmokers                    Don't Let Me Down     4879
# 236              J Balvin                                 Bobo     4520
# 253         Calvin Harris            This Is What You Came For     3194
# 261            Ed Sheeran                           Photograph     2919
# 273            Ed Sheeran                    Thinking Out Loud     2430
# 288              J Balvin                                Ginza     2135
# 296      The Chainsmokers                          All We Know     2047
# 309                 Drake                            Fake Love     1888
# 341                 Drake                             Too Good     1548
# 375         Calvin Harris                How Deep Is Your Love     1291
# ...                   ...                                  ...      ...
# 3440920  The Chainsmokers                                Paris     3038
# 3440928        Ed Sheeran                    Thinking Out Loud     2849
# 3440943        Ed Sheeran                          Galway Girl     2712
# 3440952    Kendrick Lamar                              HUMBLE.     2557
# 3440977       Post Malone                      Congratulations     2251
# 3440990        Ed Sheeran                   Castle on the Hill     2206
# 3440992  The Chainsmokers                    Don't Let Me Down     2198
# 3441009        Ed Sheeran                         Shape of You     8969
# 3441012        Ed Sheeran  Perfect Duet (Ed Sheeran & Beyoncé)     8745
# 3441015    Kendrick Lamar             All The Stars (with SZA)     8500
# 3441016        Ed Sheeran                              Perfect     8331
# 3441023       Post Malone                             rockstar     7324
# 3441024  The Chainsmokers             Something Just Like This     7273
# 3441047  The Chainsmokers                               Closer     5282
# 3441052        Luis Fonsi                    Despacito - Remix     4906
# 3441064   Imagine Dragons                              Thunder     4377
# 3441066       Post Malone                         I Fall Apart     4258
# 3441067        Luis Fonsi                      Échame La Culpa     4243
# 3441070       Post Malone                          Candy Paint     4150
# 3441080    Kendrick Lamar                  LOVE. FEAT. ZACARI.     4003
# 3441088        Ed Sheeran                           Photograph     3697
# 3441108   Imagine Dragons                             Believer     3252
# 3441121  The Chainsmokers                                Paris     3037
# 3441134        Ed Sheeran                          Galway Girl     2747
# 3441136    Kendrick Lamar                              HUMBLE.     2726
# 3441137        Ed Sheeran                    Thinking Out Loud     2726
# 3441170       Post Malone                      Congratulations     2309
# 3441174  The Chainsmokers                    Don't Let Me Down     2277
# 3441190        Ed Sheeran                   Castle on the Hill     2134
# 3441191   Imagine Dragons                    Whatever It Takes     2130
#
# [471916 rows x 3 columns]

# %%
# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df['Artist Rank'] = df['Artist'].map(sorterIndex)
# sort the dataframe
df.sort(['Artist'], ascending = [True], inplace = True)
df.drop('Artist Rank', 1, inplace = True)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-58540df840f1> in <module>()
#       5 df['Artist Rank'] = df['Artist'].map(sorterIndex)
#       6 # sort the dataframe
# ----> 7 df.sort(['Artist'], ascending = [True], inplace = True)
#       8 df.drop('Artist Rank', 1, inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df['Artist Rank'] = df['Artist'].map(sorterIndex)
# sort the dataframe
df.sort_value(['Artist'], ascending = [True], inplace = True)
df.drop('Artist Rank', 1, inplace = True)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-ecc67560dd95> in <module>()
#       5 df['Artist Rank'] = df['Artist'].map(sorterIndex)
#       6 # sort the dataframe
# ----> 7 df.sort_value(['Artist'], ascending = [True], inplace = True)
#       8 df.drop('Artist Rank', 1, inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df['Artist Rank'] = df['Artist'].map(sorterIndex)
# sort the dataframe
df.sort_values(['Artist'], ascending = [True], inplace = True)
df.drop('Artist Rank', 1, inplace = True)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#                Artist                            Track Name  Streams
# 2342911  #TocoParaVos                         Hasta la luna     1586
# 2364746  #TocoParaVos          Uh amor (feat. Lionel Ferro)     1496
# 2378791  #TocoParaVos                        Tengo un vicio     1856
# 2370945  #TocoParaVos          Uh amor (feat. Lionel Ferro)     1147
# 2361529  #TocoParaVos                         Hasta la luna     1095
# 2336853  #TocoParaVos                          Una historia     1098
# 2393423  #TocoParaVos                        Tengo un vicio     1416
# 2336852  #TocoParaVos  Enganchado #TocoParaVos - Cumbia Mix     1101
# 2363860  #TocoParaVos          Uh amor (feat. Lionel Ferro)     1778
# 2350502  #TocoParaVos                         Hasta la luna     1510
# 2398574  #TocoParaVos               Me provoca (Noche loca)     2011
# 2366350  #TocoParaVos          Uh amor (feat. Lionel Ferro)     1512
# 2382040  #TocoParaVos          Uh amor (feat. Lionel Ferro)     1201
# 2340601  #TocoParaVos                          Tan infinito     1576
# 2357390  #TocoParaVos                         Hasta la luna     1054
# 2398576  #TocoParaVos                        Tengo un vicio     1981
# 2392429  #TocoParaVos                        Tengo un vicio     1472
# 2347615  #TocoParaVos                          Vale la pena     1162
# 2351642  #TocoParaVos                         Hasta la luna     1254
# 2350524  #TocoParaVos                          Vale la pena     1268
# 2340588  #TocoParaVos                          Vale la pena     1768
# 2342386  #TocoParaVos                          Vale la pena     1341
# 2360070  #TocoParaVos          Uh amor (feat. Lionel Ferro)     1761
# 2336826  #TocoParaVos  Tu beso y tu piel (feat. Gustas Mio)     1203
# 2355032  #TocoParaVos                         Hasta la luna     1526
# 2333198  #TocoParaVos  Tu beso y tu piel (feat. Gustas Mio)     1301
# 2368710  #TocoParaVos                         Hasta la luna     1158
# 2345658  #TocoParaVos                          Vale la pena     1438
# 2334972  #TocoParaVos                         Hasta la luna     2030
# 2377019  #TocoParaVos                        Tengo un vicio     1655
# ...               ...                                   ...      ...
# 3285870           NaN                                   NaN    82477
# 3285885           NaN                                   NaN    65288
# 3286126           NaN                                   NaN    29983
# 3286321           NaN                                   NaN    30171
# 3330726           NaN                                   NaN     2879
# 3330731           NaN                                   NaN     2449
# 3330749           NaN                                   NaN     1803
# 3330787           NaN                                   NaN     2776
# 3330797           NaN                                   NaN     2074
# 3330814           NaN                                   NaN     1681
# 3353257           NaN                                   NaN     5137
# 3353259           NaN                                   NaN     4640
# 3353279           NaN                                   NaN     2637
# 3353296           NaN                                   NaN     1856
# 3353332           NaN                                   NaN     4805
# 3353333           NaN                                   NaN     4138
# 3353359           NaN                                   NaN     2439
# 3353374           NaN                                   NaN     1938
# 3406398           NaN                                   NaN    13297
# 3406402           NaN                                   NaN    11287
# 3406420           NaN                                   NaN     7202
# 3406435           NaN                                   NaN     5753
# 3406601           NaN                                   NaN    12432
# 3406612           NaN                                   NaN     9322
# 3406633           NaN                                   NaN     6452
# 3406651           NaN                                   NaN     5413
# 3406883           NaN                                   NaN     3426
# 3407072           NaN                                   NaN     3082
# 3432077           NaN                                   NaN     3397
# 3432383           NaN                                   NaN     1997
#
# [3441197 rows x 3 columns]

# %%
# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# sort the dataframe
df_result.sort_values(['Artist'], ascending = [True], inplace = True)
# remove the added column for ranking
df_result.drop('Artist Rank', 1, inplace = True)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_result
# Out:
#                    Artist                 Track Name  Streams
# 2080870     Calvin Harris                 Heatstroke     3182
# 2113183     Calvin Harris                      Feels    12632
# 1509078     Calvin Harris  This Is What You Came For    18252
# 305138      Calvin Harris                     My Way    11788
# 305180      Calvin Harris  This Is What You Came For     9756
# 1214829     Calvin Harris                      Feels    57144
# 2793513     Calvin Harris                     Rollin     5867
# 637367      Calvin Harris  This Is What You Came For     4949
# 3039497     Calvin Harris                      Slide     1181
# 1214892     Calvin Harris                     My Way    41575
# 840610      Calvin Harris                      Slide   202746
# 3039473     Calvin Harris                      Slide     1127
# 2980902     Calvin Harris                     My Way     2728
# 1214901     Calvin Harris  This Is What You Came For    39885
# 674938      Calvin Harris                      Slide     6365
# 305346      Calvin Harris                     My Way     9568
# 3296252     Calvin Harris                      Feels   135084
# 1508994     Calvin Harris                     My Way    30680
# 2285691     Calvin Harris                     My Way     2616
# 2608058     Calvin Harris                 Heatstroke     8284
# 2224861     Calvin Harris  This Is What You Came For    48756
# 1509402     Calvin Harris                     My Way    31166
# 1981834     Calvin Harris                     My Way    20107
# 1214691     Calvin Harris                     My Way    39917
# 3039519     Calvin Harris                      Slide     1177
# 1214701     Calvin Harris  This Is What You Came For    38150
# 490261      Calvin Harris                      Slide    45002
# 2608016     Calvin Harris                      Slide    21385
# 2793519     Calvin Harris                     My Way     5739
# 3296328     Calvin Harris                      Slide    32138
# ...                   ...                        ...      ...
# 2786496  The Chainsmokers                      Paris     6628
# 1233454  The Chainsmokers                     Closer    59678
# 1233377  The Chainsmokers   Something Just Like This   100293
# 650143   The Chainsmokers          Don't Let Me Down     5405
# 3131468  The Chainsmokers                     Closer  1917618
# 650158   The Chainsmokers                      Paris     5054
# 2004090  The Chainsmokers                     Honest     2099
# 1790763  The Chainsmokers   Something Just Like This    11235
# 1233305  The Chainsmokers          Don't Let Me Down    45871
# 2004117  The Chainsmokers                    My Type     1931
# 1233504  The Chainsmokers          Don't Let Me Down    45974
# 2450525  The Chainsmokers   Something Just Like This   137624
# 3131528  The Chainsmokers          Don't Let Me Down   816552
# 2450533  The Chainsmokers                      Paris   121272
# 3131649  The Chainsmokers   Something Just Like This  3561983
# 1233675  The Chainsmokers                     Closer    63017
# 2004163  The Chainsmokers                      Paris    15527
# 649833   The Chainsmokers   Something Just Like This    16961
# 2004161  The Chainsmokers   Something Just Like This    19763
# 1233577  The Chainsmokers   Something Just Like This   111297
# 2004148  The Chainsmokers                      Young     1739
# 649864   The Chainsmokers                     Closer     8471
# 2786432  The Chainsmokers   Something Just Like This    19379
# 2004140  The Chainsmokers                  Don't Say     1766
# 3131567  The Chainsmokers                All We Know   638960
# 649924   The Chainsmokers          Don't Let Me Down     5350
# 649926   The Chainsmokers                      Paris     5314
# 2004137  The Chainsmokers           It Won't Kill Ya     1780
# 3131449  The Chainsmokers                      Paris  3189737
# 528639   The Chainsmokers   Something Just Like This    66734
#
# [471916 rows x 3 columns]

# %%
artistTop10
# Out:
# ['Ed Sheeran',
#  'Drake',
#  'The Chainsmokers',
#  'Post Malone',
#  'Kendrick Lamar',
#  'Luis Fonsi',
#  'J Balvin',
#  'Calvin Harris',
#  'Imagine Dragons',
#  'DJ Khaled']

# %%
# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
# 2004140  The Chainsmokers                  Don't Say     1766            2
# 3131567  The Chainsmokers                All We Know   638960            2
# 649924   The Chainsmokers          Don't Let Me Down     5350            2
# 649926   The Chainsmokers                      Paris     5314            2
# 2004137  The Chainsmokers           It Won't Kill Ya     1780            2
# 3131449  The Chainsmokers                      Paris  3189737            2
# 528639   The Chainsmokers   Something Just Like This    66734            2
#
# [471916 rows x 4 columns]

# %%
import pandas as pd

# aggregate and sort
df = pd.read_csv('data.csv')
df = df.groupby('Artist').sum()
artist = artist.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

df = df[['Artist', 'Track Name', 'Streams']]

# filter dataframe with the artist in the top 10 artist list
df_result = df[df['Artist'].isin(artistTop10)]

# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# sort the dataframe
df_result.sort_values(['Artist'], ascending = [True], inplace = True)
# remove the added column for ranking
df_result.drop('Artist Rank', 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-4054e953d2bc> in <module>()
#      10 artistTop10 = artistTop10.index.tolist()
#      11
# ---> 12 df = df[['Artist', 'Track Name', 'Streams']]
#      13
#      14 # filter dataframe with the artist in the top 10 artist list
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['Artist' 'Track Name'] not in index"

# %%
import pandas as pd

# aggregate and sort
df = pd.read_csv('data.csv')
df = df.groupby('Artist').sum()
artist = artist.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

# %%
df = df[['Artist', 'Track Name', 'Streams']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-83a89dfdadd4> in <module>()
# ----> 1 df = df[['Artist', 'Track Name', 'Streams']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['Artist' 'Track Name'] not in index"

# %%
df
# Out:
#                    Position     Streams
# Artist
# #TocoParaVos         101278     3485730
# $uicideBoy$            1257       44258
# *NSYNC                14228     7484201
# -M-                     147       43037
# 070 Shake               547       31035
# 100%                    188        2465
# 101Barz                 690       81269
# 10cm                  12711      247144
# 12:00                   560        6706
# 13 Block               2836      853726
# 13 Crowns               622        8652
# 16yrold                2113      235239
# 187 Strassenbande    182088    88355831
# 1987                    161       23914
# 1Kilo                 46247    74279422
# 2 Chainz             201213   358556483
# 21 Savage            825054  1127824035
# 22 Savage              4513    12126721
# 24Heavy                 294        7525
# 257ers                34159     6365229
# 2NE1                   5097      118844
# 2Pac                    756      716046
# 3 Doors Down            371        6518
# 30Y                    4138       28905
# 3robi                 21281     5764078
# 4 Non Blondes           638       61852
# 4Keus Gang            11463     3699534
# 5 After Midnight      11359     3172245
# 50 Cent                4419      848913
# 53A                      80        7124
# ...                     ...         ...
# 阿達                     5845      193172
# 陳以桐                   41483      988144
# 陳嘉唯                    5837      121959
# 陳念澤                     360       10340
# 陳思函                    2014       44394
# 陳惠婷                    1063       30678
# 陳李張王                    156        2853
# 陳毓芸                     199        3825
# 陳洛                      327       11035
# 陳潔儀                    1345       56703
# 陶晶瑩                    3565       58375
# 雀斑                      206        8235
# 順子                     1242       27838
# 顏力妃                    1104       19114
# 馬雲                     1272       43124
# 魯向卉                     833       18751
# 黃小楨                     161        3509
# 黃小琥                    1216       23952
# 黃渤                      581       14237
# 黃湘怡                     347        5169
# 黃玠                     4369      165980
# 黃立行                     150        3020
# 黃維德                     134        3188
# 黃義達                     734       20702
# 黃聖萊Lex                  424       11070
# 黃荻鈞                     179        7733
# 黄靖伦                     790       13319
# 鼓鼓                     5397      103230
# 齊晨                      359        5291
# 龔詩嘉                     121        5185
#
# [6628 rows x 2 columns]

# %%
import pandas as pd

# aggregate and sort
df_0 = pd.read_csv('data.csv')
df = df_0.groupby('Artist').sum()
artist = artist.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

df = df_0[['Artist', 'Track Name', 'Streams']]

# filter dataframe with the artist in the top 10 artist list
df_result = df[df['Artist'].isin(artistTop10)]

# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# sort the dataframe
df_result.sort_values(['Artist'], ascending = [True], inplace = True)
# remove the added column for ranking
df_result.drop('Artist Rank', 1, inplace = True)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_result
# Out:
#                    Artist                 Track Name  Streams
# 2080870     Calvin Harris                 Heatstroke     3182
# 2113183     Calvin Harris                      Feels    12632
# 1509078     Calvin Harris  This Is What You Came For    18252
# 305138      Calvin Harris                     My Way    11788
# 305180      Calvin Harris  This Is What You Came For     9756
# 1214829     Calvin Harris                      Feels    57144
# 2793513     Calvin Harris                     Rollin     5867
# 637367      Calvin Harris  This Is What You Came For     4949
# 3039497     Calvin Harris                      Slide     1181
# 1214892     Calvin Harris                     My Way    41575
# 840610      Calvin Harris                      Slide   202746
# 3039473     Calvin Harris                      Slide     1127
# 2980902     Calvin Harris                     My Way     2728
# 1214901     Calvin Harris  This Is What You Came For    39885
# 674938      Calvin Harris                      Slide     6365
# 305346      Calvin Harris                     My Way     9568
# 3296252     Calvin Harris                      Feels   135084
# 1508994     Calvin Harris                     My Way    30680
# 2285691     Calvin Harris                     My Way     2616
# 2608058     Calvin Harris                 Heatstroke     8284
# 2224861     Calvin Harris  This Is What You Came For    48756
# 1509402     Calvin Harris                     My Way    31166
# 1981834     Calvin Harris                     My Way    20107
# 1214691     Calvin Harris                     My Way    39917
# 3039519     Calvin Harris                      Slide     1177
# 1214701     Calvin Harris  This Is What You Came For    38150
# 490261      Calvin Harris                      Slide    45002
# 2608016     Calvin Harris                      Slide    21385
# 2793519     Calvin Harris                     My Way     5739
# 3296328     Calvin Harris                      Slide    32138
# ...                   ...                        ...      ...
# 2786496  The Chainsmokers                      Paris     6628
# 1233454  The Chainsmokers                     Closer    59678
# 1233377  The Chainsmokers   Something Just Like This   100293
# 650143   The Chainsmokers          Don't Let Me Down     5405
# 3131468  The Chainsmokers                     Closer  1917618
# 650158   The Chainsmokers                      Paris     5054
# 2004090  The Chainsmokers                     Honest     2099
# 1790763  The Chainsmokers   Something Just Like This    11235
# 1233305  The Chainsmokers          Don't Let Me Down    45871
# 2004117  The Chainsmokers                    My Type     1931
# 1233504  The Chainsmokers          Don't Let Me Down    45974
# 2450525  The Chainsmokers   Something Just Like This   137624
# 3131528  The Chainsmokers          Don't Let Me Down   816552
# 2450533  The Chainsmokers                      Paris   121272
# 3131649  The Chainsmokers   Something Just Like This  3561983
# 1233675  The Chainsmokers                     Closer    63017
# 2004163  The Chainsmokers                      Paris    15527
# 649833   The Chainsmokers   Something Just Like This    16961
# 2004161  The Chainsmokers   Something Just Like This    19763
# 1233577  The Chainsmokers   Something Just Like This   111297
# 2004148  The Chainsmokers                      Young     1739
# 649864   The Chainsmokers                     Closer     8471
# 2786432  The Chainsmokers   Something Just Like This    19379
# 2004140  The Chainsmokers                  Don't Say     1766
# 3131567  The Chainsmokers                All We Know   638960
# 649924   The Chainsmokers          Don't Let Me Down     5350
# 649926   The Chainsmokers                      Paris     5314
# 2004137  The Chainsmokers           It Won't Kill Ya     1780
# 3131449  The Chainsmokers                      Paris  3189737
# 528639   The Chainsmokers   Something Just Like This    66734
#
# [471916 rows x 3 columns]

# %%
sorterIndex
# Out:
# {'Calvin Harris': 7,
#  'DJ Khaled': 9,
#  'Drake': 1,
#  'Ed Sheeran': 0,
#  'Imagine Dragons': 8,
#  'J Balvin': 6,
#  'Kendrick Lamar': 4,
#  'Luis Fonsi': 5,
#  'Post Malone': 3,
#  'The Chainsmokers': 2}

# %%
artistTop10
# Out:
# ['Ed Sheeran',
#  'Drake',
#  'The Chainsmokers',
#  'Post Malone',
#  'Kendrick Lamar',
#  'Luis Fonsi',
#  'J Balvin',
#  'Calvin Harris',
#  'Imagine Dragons',
#  'DJ Khaled']

# %%
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Artist Rank'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-e34bdec98dd6> in <module>()
# ----> 1 df = df.sort_values(by='Artist Rank', ascending=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3617
#    3618             by = by[0]
# -> 3619             k = self.xs(by, axis=other_axis).values
#    3620             if k.ndim == 2:
#    3621
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    2333
#    2334         if axis == 1:
# -> 2335             return self[key]
#    2336
#    2337         self._consolidate_inplace()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Artist Rank'

# %%
df_result
# Out:
#                    Artist                 Track Name  Streams  Artist Rank
# 2080870     Calvin Harris                 Heatstroke     3182            7
# 2113183     Calvin Harris                      Feels    12632            7
# 1509078     Calvin Harris  This Is What You Came For    18252            7
# 305138      Calvin Harris                     My Way    11788            7
# 305180      Calvin Harris  This Is What You Came For     9756            7
# 1214829     Calvin Harris                      Feels    57144            7
# 2793513     Calvin Harris                     Rollin     5867            7
# 637367      Calvin Harris  This Is What You Came For     4949            7
# 3039497     Calvin Harris                      Slide     1181            7
# 1214892     Calvin Harris                     My Way    41575            7
# 840610      Calvin Harris                      Slide   202746            7
# 3039473     Calvin Harris                      Slide     1127            7
# 2980902     Calvin Harris                     My Way     2728            7
# 1214901     Calvin Harris  This Is What You Came For    39885            7
# 674938      Calvin Harris                      Slide     6365            7
# 305346      Calvin Harris                     My Way     9568            7
# 3296252     Calvin Harris                      Feels   135084            7
# 1508994     Calvin Harris                     My Way    30680            7
# 2285691     Calvin Harris                     My Way     2616            7
# 2608058     Calvin Harris                 Heatstroke     8284            7
# 2224861     Calvin Harris  This Is What You Came For    48756            7
# 1509402     Calvin Harris                     My Way    31166            7
# 1981834     Calvin Harris                     My Way    20107            7
# 1214691     Calvin Harris                     My Way    39917            7
# 3039519     Calvin Harris                      Slide     1177            7
# 1214701     Calvin Harris  This Is What You Came For    38150            7
# 490261      Calvin Harris                      Slide    45002            7
# 2608016     Calvin Harris                      Slide    21385            7
# 2793519     Calvin Harris                     My Way     5739            7
# 3296328     Calvin Harris                      Slide    32138            7
# ...                   ...                        ...      ...          ...
# 2786496  The Chainsmokers                      Paris     6628            2
# 1233454  The Chainsmokers                     Closer    59678            2
# 1233377  The Chainsmokers   Something Just Like This   100293            2
# 650143   The Chainsmokers          Don't Let Me Down     5405            2
# 3131468  The Chainsmokers                     Closer  1917618            2
# 650158   The Chainsmokers                      Paris     5054            2
# 2004090  The Chainsmokers                     Honest     2099            2
# 1790763  The Chainsmokers   Something Just Like This    11235            2
# 1233305  The Chainsmokers          Don't Let Me Down    45871            2
# 2004117  The Chainsmokers                    My Type     1931            2
# 1233504  The Chainsmokers          Don't Let Me Down    45974            2
# 2450525  The Chainsmokers   Something Just Like This   137624            2
# 3131528  The Chainsmokers          Don't Let Me Down   816552            2
# 2450533  The Chainsmokers                      Paris   121272            2
# 3131649  The Chainsmokers   Something Just Like This  3561983            2
# 1233675  The Chainsmokers                     Closer    63017            2
# 500600    DJ Khaled          I'm the One   183854            9
# 2119809   DJ Khaled        Wild Thoughts     7934            9
# 1271030   DJ Khaled          I'm the One     3086            9
# 919737    DJ Khaled        Wild Thoughts     8214            9
# 2886897   DJ Khaled        Wild Thoughts     7403            9
# 641400    DJ Khaled          I'm the One    50210            9
# 2887095   DJ Khaled        Wild Thoughts     7361            9
# 2949234   DJ Khaled        Wild Thoughts    30489            9
# 2321759   DJ Khaled        Wild Thoughts     1447            9
# 2949434   DJ Khaled        Wild Thoughts    31160            9
# 2025778   DJ Khaled          I'm the One    10277            9
# 1271268   DJ Khaled          I'm the One     2825            9
# 2302365   DJ Khaled        Wild Thoughts     3657            9
# 3159249   DJ Khaled          I'm the One  2839872            9
# 635599    DJ Khaled          I'm the One    56975            9
# 3219350   DJ Khaled          I'm the One     2029            9
# 2802057   DJ Khaled        Wild Thoughts     9653            9
# 500630    DJ Khaled        Wild Thoughts    71618            9
# 2887295   DJ Khaled          I'm the One     6548            9
# 3042101   DJ Khaled        Wild Thoughts     1789            9
#
# [471916 rows x 4 columns]

# %%
import pandas as pd

# aggregate and sort
df_0 = pd.read_csv('data.csv')
df = df_0.groupby('Artist').sum()
artist = artist.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

df = df_0[['Artist', 'Track Name', 'Streams']]

# filter dataframe with the artist in the top 10 artist list
df_result = df[df['Artist'].isin(artistTop10)]

# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# sort the dataframe
df_result.sort_values(['Artist Rank'], ascending = [True], inplace = True)
# remove the added column for ranking
df_result.drop('Artist Rank', 1, inplace = True)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_result
# Out:
#              Artist                           Track Name  Streams
# 2075871  Ed Sheeran                            Barcelona     3850
# 1751373  Ed Sheeran                              Perfect     9799
# 3072054  Ed Sheeran                         Shape of You   263975
# 3072013  Ed Sheeran       Hearts Don't Break Around Here    38691
# 2947708  Ed Sheeran                              Happier     9088
# 2125563  Ed Sheeran  Perfect Duet (Ed Sheeran & Beyoncé)    17812
# 2125572  Ed Sheeran                              Perfect    14018
# 1333461  Ed Sheeran                           Photograph     1404
# 787180   Ed Sheeran                          Save Myself   186197
# 787175   Ed Sheeran                       Bibia Be Ye Ye   191365
# 787174   Ed Sheeran                               Eraser   191572
# 2947711  Ed Sheeran                          Galway Girl     9015
# 2125585  Ed Sheeran                         Shape of You    11085
# 1333467  Ed Sheeran                              Perfect     1347
# 1751324  Ed Sheeran                         Shape of You    37980
# 787145   Ed Sheeran       Hearts Don't Break Around Here   213708
# 1751315  Ed Sheeran           How Would You Feel (Paean)     3682
# 787141   Ed Sheeran           How Would You Feel (Paean)   218986
# 787133   Ed Sheeran                       Nancy Mulligan   230867
# 787128   Ed Sheeran                  Supermarket Flowers   239224
# 787123   Ed Sheeran                            Barcelona   250284
# 2818096  Ed Sheeran                    Thinking Out Loud     6795
# 787113   Ed Sheeran                      What Do I Know?   276677
# 1333494  Ed Sheeran                    Thinking Out Loud     1178
# 787101   Ed Sheeran                              New Man   312611
# 1751273  Ed Sheeran                    Thinking Out Loud     4413
# 3072000  Ed Sheeran                               Eraser    40743
# 787093   Ed Sheeran                              Happier   357575
# 787089   Ed Sheeran                                 Dive   374489
# 3071999  Ed Sheeran                       Bibia Be Ye Ye    40881
# ...             ...                                  ...      ...
# 486203    DJ Khaled                          I'm the One   143854
# 2353767   DJ Khaled                          I'm the One     1324
# 1215743   DJ Khaled                          I'm the One   130987
# 3116120   DJ Khaled                        Wild Thoughts    67224
# 1215762   DJ Khaled                        Wild Thoughts    97998
# 3308499   DJ Khaled                        Wild Thoughts    47805
# 1216544   DJ Khaled                        Wild Thoughts   156221
# 2355164   DJ Khaled                          I'm the One     2551
# 1216538   DJ Khaled                          I'm the One   167879
# 2728577   DJ Khaled                          I'm the One    23765
# 3115908   DJ Khaled                        Wild Thoughts    82665
# 2728594   DJ Khaled                        Wild Thoughts    22794
# 2354994   DJ Khaled                          I'm the One     2739
# 1216340   DJ Khaled                        Wild Thoughts   156321
# 1216332   DJ Khaled                          I'm the One   173140
# 3115934   DJ Khaled                          I'm the One    68489
# 2354807   DJ Khaled                          I'm the One     3121
# 3308334   DJ Khaled                          I'm the One    37575
# 1216141   DJ Khaled                        Wild Thoughts   149062
# 2728791   DJ Khaled                          I'm the One    23967
# 1216134   DJ Khaled                          I'm the One   160679
# 3308302   DJ Khaled                        Wild Thoughts    48406
# 2354631   DJ Khaled                          I'm the One     3058
# 2891729   DJ Khaled                          I'm the One     5792
# 1215950   DJ Khaled                        Wild Thoughts   126797
# 2354477   DJ Khaled                          I'm the One     2904
# 1215938   DJ Khaled                          I'm the One   152465
# 2354324   DJ Khaled                          I'm the One     2806
# 1218738   DJ Khaled                        Wild Thoughts   157565
# 3003144   DJ Khaled                        Wild Thoughts     2708
#
# [471916 rows x 3 columns]

# %%
artistTop10
# Out:
# ['Ed Sheeran',
#  'Drake',
#  'The Chainsmokers',
#  'Post Malone',
#  'Kendrick Lamar',
#  'Luis Fonsi',
#  'J Balvin',
#  'Calvin Harris',
#  'Imagine Dragons',
#  'DJ Khaled']

# %%
import pandas as pd

# aggregate and sort
df_0 = pd.read_csv('data.csv')
df = df_0.groupby('Artist').sum()
artist = artist.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

df = df_0[['Artist', 'Track Name', 'Streams']]

# filter dataframe with the artist in the top 10 artist list
df_result = df[df['Artist'].isin(artistTop10)]

# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# sort the dataframe
df_result.sort_values(['Artist Rank', 'Streams'], ascending = [True, False], inplace = True)
# remove the added column for ranking
df_result.drop('Artist Rank', 1, inplace = True)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users
# 2325310   DJ Khaled    I'm the One     1001
# 2748169   DJ Khaled  Wild Thoughts     1001
# 3034841   DJ Khaled  Wild Thoughts     1001
#
# [471916 rows x 3 columns]

# %%
import pandas as pd

# aggregate and sort
df_0 = pd.read_csv('data.csv')
df = df_0.groupby('Artist').sum()
artist = artist.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

df = df_0[['Artist', 'Track Name', 'Streams']]
df = df.groupby('Artist', 'Track Name').sum()

# filter dataframe with the artist in the top 10 artist list
df_result = df[df['Artist'].isin(artistTop10)]

# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# sort the dataframe
df_result.sort_values(['Artist Rank', 'Streams'], ascending = [True, False], inplace = True)
# remove the added column for ranking
df_result.drop('Artist Rank', 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-4c49b0ce944f> in <module>()
#      11
#      12 df = df_0[['Artist', 'Track Name', 'Streams']]
# ---> 13 df = df.groupby('Artist', 'Track Name').sum()
#      14
#      15 # filter dataframe with the artist in the top 10 artist list
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5157         if level is None and by is None:
#    5158             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 5159         axis = self._get_axis_number(axis)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     355                 pass
#     356         raise ValueError('No axis named {0} for object type {1}'
# --> 357                          .format(axis, type(self)))
#     358
#     359     def _get_axis_name(self, axis):
#
# ValueError: No axis named Track Name for object type <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd

# aggregate and sort
df_0 = pd.read_csv('data.csv')
df = df_0.groupby('Artist').sum()
artist = artist.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

df = df_0[['Artist', 'Track Name', 'Streams']]
df = df.groupby(['Artist', 'Track Name']).sum()

# filter dataframe with the artist in the top 10 artist list
df_result = df[df['Artist'].isin(artistTop10)]

# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# sort the dataframe
df_result.sort_values(['Artist Rank', 'Streams'], ascending = [True, False], inplace = True)
# remove the added column for ranking
df_result.drop('Artist Rank', 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Artist'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-3d638b7680fd> in <module>()
#      14
#      15 # filter dataframe with the artist in the top 10 artist list
# ---> 16 df_result = df[df['Artist'].isin(artistTop10)]
#      17
#      18 # artistTop10 is the sorter
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Artist'

# %%
import pandas as pd

# aggregate and sort
df_0 = pd.read_csv('data.csv')
df = df_0.groupby('Artist').sum()
artist = df.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

df = df_0[['Artist', 'Track Name', 'Streams']]
df = df.groupby(['Artist', 'Track Name']).sum()

# filter dataframe with the artist in the top 10 artist list
df_result = df[df['Artist'].isin(artistTop10)]

# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# sort the dataframe
df_result.sort_values(['Artist Rank', 'Streams'], ascending = [True, False], inplace = True)
# remove the added column for ranking
df_result.drop('Artist Rank', 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Artist'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-e92cf0515e7e> in <module>()
#      14
#      15 # filter dataframe with the artist in the top 10 artist list
# ---> 16 df_result = df[df['Artist'].isin(artistTop10)]
#      17
#      18 # artistTop10 is the sorter
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Artist'

# %%
import pandas as pd

# aggregate and sort
df_0 = pd.read_csv('data.csv')
df = df_0.groupby('Artist').sum()
artist = df.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

df = df_0[['Artist', 'Track Name', 'Streams']]
df = df.groupby(['Artist', 'Track Name']).sum()

# %%
artistTop10
# Out:
# ['Ed Sheeran',
#  'Drake',
#  'The Chainsmokers',
#  'Post Malone',
#  'Kendrick Lamar',
#  'Luis Fonsi',
#  'J Balvin',
#  'Calvin Harris',
#  'Imagine Dragons',
#  'DJ Khaled']

# %%
df
# Out:
#                                                         Streams
# Artist            Track Name
# #TocoParaVos      Bailemos juntos                          1005
#                   Enganchado #TocoParaVos - Cumbia Mix    71467
#                   Hasta la luna                         2361379
#                   Me provoca (Noche loca)                 74753
#                   Su fiel admirador                        1026
#                   Sólo necesito                           16927
#                   Tan infinito                            82590
#                   Tengo un vicio                         343298
#                   Tu beso y tu piel (feat. Gustas Mio)    44772
#                   Uh amor (feat. Lionel Ferro)           223526
#                   Una historia                            45298
#                   Vale la pena                           219689
# $uicideBoy$       Paris                                   17598
#                   South Side Suicide (feat. Pouya)        26660
# *NSYNC            Bye Bye Bye                             40381
#                   Merry Christmas, Happy Holidays       7399914
#                   This I Promise You                      43906
# -M-               Douce Nuit                              43037
# 070 Shake         Honey                                   31035
# 100%              Sketch U                                 2465
# 101Barz           Zomersessie                             58163
#                   Zomersessie (feat. 3robi)               23106
# 10cm              Everything                               2750
#                   My eyes                                244394
# 12:00             Sumartíminn                              6706
# 13 Block          Somme                                   40715
#                   Vide                                   813011
# 13 Crowns         Grateful                                 8652
# 16yrold           No Romance                             235239
# 187 Strassenbande 10 Dinger                             1900387
# ...                                                         ...
# 陳潔儀               忽然的雨                                    39793
# 陶晶瑩               如你一般的人                                  58375
# 雀斑                我想養流浪狗                                   8235
# 順子                Dear Friend                             24803
#                   眷戀                                       3035
# 顏力妃               忙著說再見 - 偶像劇 【如朕親臨】插曲                    19114
# 馬雲                風清揚 - 《功守道》電影主題曲                        43124
# 魯向卉               釋懷前                                     18751
# 黃小楨               December Night                           3509
# 黃小琥               伴                                        6498
#                   沒那麼簡單                                    8234
#                   該放手了                                     2769
#                   重來                                       6451
# 黃渤                帶你一起丟手絹                                 14237
# 黃湘怡               第一個冬季                                    5169
# 黃玠                海邊情歌                                   133248
#                   相片蒐集簿                                   32732
# 黃立行               你身邊                                      3020
# 黃維德               那天愛離開                                    3188
# 黃義達               一秒的安慰                                    7420
#                   到底多久                                     7518
#                   匿名的寶貝                                    3127
#                   每天的每夜                                    2637
# 黃聖萊Lex            看好                                      11070
# 黃荻鈞               半年                                       7733
# 黄靖伦               我會一直記得                                   2866
#                   舊傷                                      10453
# 鼓鼓                為愛而愛                                   103230
# 齊晨                到此為止                                     5291
# 龔詩嘉               My Island Home                           5185
#
# [19922 rows x 1 columns]

# %%
# filter dataframe with the artist in the top 10 artist list
df_result = df[df['Artist'].isin(artistTop10)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Artist'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-f251fc612fcb> in <module>()
#       1 # filter dataframe with the artist in the top 10 artist list
# ----> 2 df_result = df[df['Artist'].isin(artistTop10)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Artist'

# %%
df = df.reset_index()

# %%
df
# Out:
#                   Artist                            Track Name  Streams
# 0           #TocoParaVos                       Bailemos juntos     1005
# 1           #TocoParaVos  Enganchado #TocoParaVos - Cumbia Mix    71467
# 2           #TocoParaVos                         Hasta la luna  2361379
# 3           #TocoParaVos               Me provoca (Noche loca)    74753
# 4           #TocoParaVos                     Su fiel admirador     1026
# 5           #TocoParaVos                         Sólo necesito    16927
# 6           #TocoParaVos                          Tan infinito    82590
# 7           #TocoParaVos                        Tengo un vicio   343298
# 8           #TocoParaVos  Tu beso y tu piel (feat. Gustas Mio)    44772
# 9           #TocoParaVos          Uh amor (feat. Lionel Ferro)   223526
# 10          #TocoParaVos                          Una historia    45298
# 11          #TocoParaVos                          Vale la pena   219689
# 12           $uicideBoy$                                 Paris    17598
# 13           $uicideBoy$      South Side Suicide (feat. Pouya)    26660
# 14                *NSYNC                           Bye Bye Bye    40381
# 15                *NSYNC       Merry Christmas, Happy Holidays  7399914
# 16                *NSYNC                    This I Promise You    43906
# 17                   -M-                            Douce Nuit    43037
# 18             070 Shake                                 Honey    31035
# 19                  100%                              Sketch U     2465
# 20               101Barz                           Zomersessie    58163
# 21               101Barz             Zomersessie (feat. 3robi)    23106
# 22                  10cm                            Everything     2750
# 23                  10cm                               My eyes   244394
# 24                 12:00                           Sumartíminn     6706
# 25              13 Block                                 Somme    40715
# 26              13 Block                                  Vide   813011
# 27             13 Crowns                              Grateful     8652
# 28               16yrold                            No Romance   235239
# 29     187 Strassenbande                             10 Dinger  1900387
# ...                  ...                                   ...      ...
# 19892                陳潔儀                                  忽然的雨    39793
# 19893                陶晶瑩                                如你一般的人    58375
# 19894                 雀斑                                我想養流浪狗     8235
# 19895                 順子                           Dear Friend    24803
# 19896                 順子                                    眷戀     3035
# 19897                顏力妃                  忙著說再見 - 偶像劇 【如朕親臨】插曲    19114
# 19898                 馬雲                      風清揚 - 《功守道》電影主題曲    43124
# 19899                魯向卉                                   釋懷前    18751
# 19900                黃小楨                        December Night     3509
# 19901                黃小琥                                     伴     6498
# 19902                黃小琥                                 沒那麼簡單     8234
# 19903                黃小琥                                  該放手了     2769
# 19904                黃小琥                                    重來     6451
# 19905                 黃渤                               帶你一起丟手絹    14237
# 19906                黃湘怡                                 第一個冬季     5169
# 19907                 黃玠                                  海邊情歌   133248
# 19908                 黃玠                                 相片蒐集簿    32732
# 19909                黃立行                                   你身邊     3020
# 19910                黃維德                                 那天愛離開     3188
# 19911                黃義達                                 一秒的安慰     7420
# 19912                黃義達                                  到底多久     7518
# 19913                黃義達                                 匿名的寶貝     3127
# 19914                黃義達                                 每天的每夜     2637
# 19915             黃聖萊Lex                                    看好    11070
# 19916                黃荻鈞                                    半年     7733
# 19917                黄靖伦                                我會一直記得     2866
# 19918                黄靖伦                                    舊傷    10453
# 19919                 鼓鼓                                  為愛而愛   103230
# 19920                 齊晨                                  到此為止     5291
# 19921                龔詩嘉                        My Island Home     5185
#
# [19922 rows x 3 columns]

# %%
import pandas as pd

# aggregate and sort
df_0 = pd.read_csv('data.csv')
df = df_0.groupby('Artist').sum()
artist = df.sort_values(by='Streams', ascending=False)

# get the top 10 artist list
artistTop10 = artist.head(10)
artistTop10 = artistTop10.index.tolist()

df = df_0[['Artist', 'Track Name', 'Streams']]
df = df.groupby(['Artist', 'Track Name']).sum()
df = df.reset_index()

# filter dataframe with the artist in the top 10 artist list
df_result = df[df['Artist'].isin(artistTop10)]

# artistTop10 is the sorter
# create the dictionary that defines the order of sorting
sorterIndex = dict(zip(artistTop10, range(len(artistTop10))))
# generate a rank column that will be used to sort the dataframe numerically
df_result['Artist Rank'] = df_result['Artist'].map(sorterIndex)
# sort the dataframe
df_result.sort_values(['Artist Rank', 'Streams'], ascending = [True, False], inplace = True)
# remove the added column for ranking
df_result.drop('Artist Rank', 1, inplace = True)
# Out:
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\dsunae\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_result
# Out:
#                Artist                                         Track Name  \
# 4722       Ed Sheeran                                       Shape of You
# 4714       Ed Sheeran                                            Perfect
# 4685       Ed Sheeran                                 Castle on the Hill
# 4698       Ed Sheeran                                        Galway Girl
# 4720       Ed Sheeran                                         Photograph
# 4701       Ed Sheeran                                            Happier
# 4734       Ed Sheeran                                  Thinking Out Loud
# 4690       Ed Sheeran                                               Dive
# 4718       Ed Sheeran                Perfect Duet (Ed Sheeran & Beyoncé)
# 4737       Ed Sheeran                                    What Do I Know?
# 4712       Ed Sheeran                                            New Man
# 4703       Ed Sheeran                         How Would You Feel (Paean)
# 4731       Ed Sheeran                                Supermarket Flowers
# 4682       Ed Sheeran                                          Barcelona
# 4711       Ed Sheeran                                     Nancy Mulligan
# 4702       Ed Sheeran                     Hearts Don't Break Around Here
# 4694       Ed Sheeran                                             Eraser
# 4683       Ed Sheeran                                     Bibia Be Ye Ye
# 4721       Ed Sheeran                                        Save Myself
# 4723       Ed Sheeran   Shape of You (Latin Remix) [feat. Zion & Lennox]
# 4704       Ed Sheeran                                         I See Fire
# 4727       Ed Sheeran                       Shape of You - Stormzy Remix
# 4732       Ed Sheeran                                       Tenerife Sea
# 4733       Ed Sheeran                                         The A Team
# 4691       Ed Sheeran                                              Don't
# 4725       Ed Sheeran                            Shape of You - Acoustic
# 4724       Ed Sheeran  Shape of You (Major Lazer Remix) [feat. Nyla &...
# 4719       Ed Sheeran     Perfect Symphony (Ed Sheeran & Andrea Bocelli)
# 4700       Ed Sheeran                                       Give Me Love
# 4699       Ed Sheeran                  Galway Girl - Martin Jensen Remix
# ...               ...                                                ...
# 7310  Imagine Dragons                                          Yesterday
# 7291  Imagine Dragons                                Dancing In The Dark
# 7297  Imagine Dragons                                On Top Of The World
# 7305  Imagine Dragons  Thunder / Young Dumb & Broke (with Khalid) - M...
# 7307  Imagine Dragons                                           Warriors
# 7303  Imagine Dragons             Thunder (With K.Flay) - Official Remix
# 7309  Imagine Dragons           Whatever It Takes - Jorgen Odegard Remix
# 7300  Imagine Dragons                              Shots - Broiler Remix
# 7294  Imagine Dragons                                          It's Time
# 7304  Imagine Dragons                            Thunder - Live/Acoustic
# 3590        DJ Khaled                                        I'm the One
# 3601        DJ Khaled                                      Wild Thoughts
# 3599        DJ Khaled                                         To the Max
# 3584        DJ Khaled                                         Don't Quit
# 3597        DJ Khaled                                            Shining
# 3595        DJ Khaled                                      On Everything
# 3591        DJ Khaled                                   Iced Out My Arms
# 3589        DJ Khaled                                 I Love You so Much
# 3585        DJ Khaled                                      Down for Life
# 3588        DJ Khaled                                   I Can't Even Lie
# 3592        DJ Khaled                                       It's Secured
# 3593        DJ Khaled                                    Major Bag Alert
# 3594        DJ Khaled                                             Nobody
# 3582        DJ Khaled                            (Intro) I'm so Grateful
# 3596        DJ Khaled                                       Pull a Caper
# 3587        DJ Khaled                                           Good Man
# 3600        DJ Khaled                                           Whatever
# 3598        DJ Khaled                   That Range Rover Came With Steps
# 3586        DJ Khaled                                           For Free
# 3583        DJ Khaled                                        Do You Mind
#
#          Streams
# 4722  2993988783
# 4714  1008408812
# 4685   950641030
# 4698   895638000
# 4720   441132246
# 4701   396550634
# 4734   378317823
# 4690   250391699
# 4718   211662492
# 4737   184236454
# 4712   165061869
# 4703   158975388
# 4731   142213824
# 4682   130094807
# 4711   102351367
# 4702    94452753
# 4694    88679551
# 4683    75939105
# 4721    68764853
# 4723    34355823
# 4704    33374939
# 4727    20779295
# 4732    16897317
# 4733    15096376
# 4691    11382067
# 4725     7349968
# 4724     6141094
# 4719     5400717
# 4700     5051937
# 4699     4445160
# ...          ...
# 7310     1856645
# 7291      929413
# 7297      571052
# 7305      500732
# 7307      383634
# 7303       79939
# 7309       15976
# 7300        9497
# 7294        4009
# 7304        3062
# 3590  1254196301
# 3601   899312362
# 3599    31286677
# 3584    22337446
# 3597    17265613
# 3595     2836293
# 3591     1675466
# 3589     1455389
# 3585     1198808
# 3588     1152628
# 3592     1120711
# 3593      652026
# 3594      345069
# 3582      277571
# 3596      235606
# 3587      227563
# 3600      211116
# 3598      210753
# 3586      143765
# 3583       83096
#
# [245 rows x 3 columns]
